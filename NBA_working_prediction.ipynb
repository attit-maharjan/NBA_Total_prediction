# %%
pip install catboost xgboost nba_api
# Out:
# Collecting catboost
#   Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Collecting nba_api
#   Downloading nba_api-1.11.4-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.29.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from nba_api) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (2026.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)
# Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 6.5 MB/s eta 0:00:00
# Downloading nba_api-1.11.4-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.6/322.6 kB 12.1 MB/s eta 0:00:00
# Installing collected packages: nba_api, catboost
# Successfully installed catboost-1.2.10 nba_api-1.11.4

# %%
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import leaguegamelog, leaguedashteamstats
from datetime import datetime
import time

# First, get your game log data
SEASON = "2025-26"
SEASON_TYPE = "Regular Season"

print("Fetching game log data...")
df_games = leaguegamelog.LeagueGameLog(
    season=SEASON,
    season_type_all_star=SEASON_TYPE,
    timeout=120
).get_data_frames()[0]

print(f"Raw data shape: {df_games.shape}")
print(f"Games in dataset: {len(df_games) // 2} (each game appears twice)")

# Now fetch team advanced stats for the season
print("\nFetching team advanced stats...")
team_advanced = leaguedashteamstats.LeagueDashTeamStats(
    season=SEASON,
    season_type_all_star=SEASON_TYPE,
    measure_type_detailed_defense='Advanced',
    per_mode_detailed='PerGame',
    timeout=120
).get_data_frames()[0]

print(f"Team advanced stats shape: {team_advanced.shape}")
print("Advanced stats columns:", [col for col in team_advanced.columns if col in
      ['OFF_RATING', 'DEF_RATING', 'NET_RATING', 'PACE', 'TS_PCT', 'EFG_PCT',
       'OREB_PCT', 'DREB_PCT', 'TM_TOV_PCT', 'AST_RATIO', 'PIE']])

def process_games_to_model_format(df_games, team_advanced):
    """
    Transform game log into the format your model needs
    """
    print("\nProcessing games into model format...")

    # Get unique game IDs
    game_ids = df_games['GAME_ID'].unique()
    print(f"Found {len(game_ids)} unique games")

    processed_games = []

    for i, game_id in enumerate(game_ids):
        if i % 50 == 0:
            print(f"  Processing game {i}/{len(game_ids)}...")

        # Get both entries for this game
        game_entries = df_games[df_games['GAME_ID'] == game_id]

        if len(game_entries) != 2:
            print(f"    Warning: Game {game_id} has {len(game_entries)} entries, skipping")
            continue

        # Determine home and away
        team1 = game_entries.iloc[0]
        team2 = game_entries.iloc[1]

        # Check if IS_HOME_GAME column exists
        if 'IS_HOME_GAME' in df_games.columns:
            home_entry = team1 if team1['IS_HOME_GAME'] else team2
            away_entry = team2 if team1['IS_HOME_GAME'] else team1
        else:
            # Fallback to MATCHUP column logic
            if 'vs.' in str(team1['MATCHUP']):
                home_entry, away_entry = team1, team2
            else:
                home_entry, away_entry = team2, team1

        # Get team advanced stats
        home_team_id = home_entry['TEAM_ID']
        away_team_id = away_entry['TEAM_ID']

        home_adv = team_advanced[team_advanced['TEAM_ID'] == home_team_id]
        away_adv = team_advanced[team_advanced['TEAM_ID'] == away_team_id]

        if len(home_adv) == 0 or len(away_adv) == 0:
            print(f"    Warning: Missing advanced stats for game {game_id}")
            continue

        home_adv = home_adv.iloc[0]
        away_adv = away_adv.iloc[0]

        # Parse game date
        try:
            game_date = pd.to_datetime(home_entry['GAME_DATE'])
        except:
            game_date = datetime.now()

        # Create the game record in your model's format
        game_record = {
            # Basic game info
            'GAME_ID': game_id,
            'GAME_DATE': game_date,
            'SEASON': SEASON,
            'HOME_TEAM': home_entry['TEAM_NAME'],
            'AWAY_TEAM': away_entry['TEAM_NAME'],
            'HOME_PTS': int(home_entry['PTS']),
            'AWAY_PTS': int(away_entry['PTS']),
            'TOTAL_PTS': int(home_entry['PTS'] + away_entry['PTS']),

            # Home advanced stats
            'HOME_ADV_OFF_RATING': home_adv.get('OFF_RATING', np.nan),
            'HOME_ADV_DEF_RATING': home_adv.get('DEF_RATING', np.nan),
            'HOME_ADV_NET_RATING': home_adv.get('NET_RATING', np.nan),
            'HOME_ADV_PACE': home_adv.get('PACE', np.nan),
            'HOME_ADV_TS_PCT': home_adv.get('TS_PCT', np.nan),
            'HOME_ADV_EFG_PCT': home_adv.get('EFG_PCT', np.nan),
            'HOME_ADV_OREB_PCT': home_adv.get('OREB_PCT', np.nan),
            'HOME_ADV_DREB_PCT': home_adv.get('DREB_PCT', np.nan),
            'HOME_ADV_TM_TOV_PCT': home_adv.get('TM_TOV_PCT', np.nan),
            'HOME_ADV_AST_RATIO': home_adv.get('AST_RATIO', np.nan),
            'HOME_ADV_PIE': home_adv.get('PIE', np.nan),

            # Away advanced stats
            'AWAY_ADV_OFF_RATING': away_adv.get('OFF_RATING', np.nan),
            'AWAY_ADV_DEF_RATING': away_adv.get('DEF_RATING', np.nan),
            'AWAY_ADV_NET_RATING': away_adv.get('NET_RATING', np.nan),
            'AWAY_ADV_PACE': away_adv.get('PACE', np.nan),
            'AWAY_ADV_TS_PCT': away_adv.get('TS_PCT', np.nan),
            'AWAY_ADV_EFG_PCT': away_adv.get('EFG_PCT', np.nan),
            'AWAY_ADV_OREB_PCT': away_adv.get('OREB_PCT', np.nan),
            'AWAY_ADV_DREB_PCT': away_adv.get('DREB_PCT', np.nan),
            'AWAY_ADV_TM_TOV_PCT': away_adv.get('TM_TOV_PCT', np.nan),
            'AWAY_ADV_AST_RATIO': away_adv.get('AST_RATIO', np.nan),
            'AWAY_ADV_PIE': away_adv.get('PIE', np.nan),

            # Rankings (if available)
            'HOME_ADV_OFF_RATING_RANK': home_adv.get('OFF_RATING_RANK', np.nan),
            'HOME_ADV_DEF_RATING_RANK': home_adv.get('DEF_RATING_RANK', np.nan),
            'HOME_ADV_NET_RATING_RANK': home_adv.get('NET_RATING_RANK', np.nan),
            'HOME_ADV_PACE_RANK': home_adv.get('PACE_RANK', np.nan),

            'AWAY_ADV_OFF_RATING_RANK': away_adv.get('OFF_RATING_RANK', np.nan),
            'AWAY_ADV_DEF_RATING_RANK': away_adv.get('DEF_RATING_RANK', np.nan),
            'AWAY_ADV_NET_RATING_RANK': away_adv.get('NET_RATING_RANK', np.nan),
            'AWAY_ADV_PACE_RANK': away_adv.get('PACE_RANK', np.nan),
        }

        processed_games.append(game_record)

    return pd.DataFrame(processed_games)

def add_derived_features(df):
    """
    Add all the derived features your model needs
    """
    print("\nAdding derived features...")

    # Calculate LINE (betting line) - simplified model based on net rating
    # You can replace this with actual line data if you have it
    df['LINE'] = 220 + (df['HOME_ADV_NET_RATING'] - df['AWAY_ADV_NET_RATING']) * 0.5
    df['LINE'] = df['LINE'].clip(200, 250).round(1)

    # Pace and offensive rating features
    df['AVG_PACE'] = (df['HOME_ADV_PACE'] + df['AWAY_ADV_PACE']) / 2
    df['AVG_OFF_RTG'] = (df['HOME_ADV_OFF_RATING'] + df['AWAY_ADV_OFF_RATING']) / 2
    df['PACE_X_OFF'] = df['AVG_PACE'] * df['AVG_OFF_RTG'] / 100

    # Matchup features
    df['PACE_DIFF'] = abs(df['HOME_ADV_PACE'] - df['AWAY_ADV_PACE'])
    df['OFF_VS_DEF'] = df['HOME_ADV_OFF_RATING'] - df['AWAY_ADV_DEF_RATING']
    df['DEF_VS_OFF'] = df['HOME_ADV_DEF_RATING'] - df['AWAY_ADV_OFF_RATING']

    # Strength indicators
    df['HOME_STRENGTH'] = df['HOME_ADV_NET_RATING'] / 100
    df['AWAY_STRENGTH'] = df['AWAY_ADV_NET_RATING'] / 100
    df['STRENGTH_DIFF'] = df['HOME_STRENGTH'] - df['AWAY_STRENGTH']

    # Shooting efficiency
    df['TS_PCT_DIFF'] = df['HOME_ADV_TS_PCT'] - df['AWAY_ADV_TS_PCT']

    # Rebounding battle
    df['REB_BATTLE'] = (df['HOME_ADV_OREB_PCT'] + df['HOME_ADV_DREB_PCT'] -
                        df['AWAY_ADV_OREB_PCT'] - df['AWAY_ADV_DREB_PCT'])

    # Turnover battle
    df['TOV_BATTLE'] = df['AWAY_ADV_TM_TOV_PCT'] - df['HOME_ADV_TM_TOV_PCT']

    # Home court advantage indicators
    df['HOME_OFF_ADV'] = df['HOME_ADV_OFF_RATING'] - df['AWAY_ADV_OFF_RATING']
    df['HOME_DEF_ADV'] = df['AWAY_ADV_DEF_RATING'] - df['HOME_ADV_DEF_RATING']

    return df

# Process the data
print("\n" + "="*60)
print("PROCESSING DATA FOR YOUR MODEL")
print("="*60)

# Transform to model format
model_df = process_games_to_model_format(df_games, team_advanced)

# Add derived features
model_df = add_derived_features(model_df)

# Sort by date
model_df = model_df.sort_values('GAME_DATE').reset_index(drop=True)

# Save the processed data
output_file = f"nba_model_data_{SEASON.replace('-', '_')}.csv"
model_df.to_csv(output_file, index=False)
print(f"\n✅ Saved processed data to {output_file}")

# Display data summary
print("\n" + "="*60)
print("DATA SUMMARY")
print("="*60)
print(f"Total games: {len(model_df)}")
print(f"Date range: {model_df['GAME_DATE'].min()} to {model_df['GAME_DATE'].max()}")
print(f"Number of columns: {len(model_df.columns)}")

# Check for missing values
missing_pct = model_df.isnull().sum() / len(model_df) * 100
missing_cols = missing_pct[missing_pct > 0].sort_values(ascending=False)
if len(missing_cols) > 0:
    print(f"\nColumns with missing values:")
    for col, pct in missing_cols.head(10).items():
        print(f"  {col}: {pct:.1f}% missing")

# Show sample of key columns
print("\nSample data (first 5 games):")
key_cols = ['GAME_DATE', 'HOME_TEAM', 'AWAY_TEAM', 'HOME_PTS', 'AWAY_PTS',
            'HOME_ADV_OFF_RATING', 'AWAY_ADV_OFF_RATING', 'LINE']
available_cols = [col for col in key_cols if col in model_df.columns]
print(model_df[available_cols].head(5).to_string())

# Verify your model's required features
print("\n" + "="*60)
print("FEATURE AVAILABILITY CHECK")
print("="*60)

# Your model's feature list from your code
required_features = [
    'HOME_ADV_OFF_RATING', 'AWAY_ADV_OFF_RATING',
    'HOME_ADV_DEF_RATING', 'AWAY_ADV_DEF_RATING',
    'HOME_ADV_NET_RATING', 'AWAY_ADV_NET_RATING',
    'HOME_ADV_PACE', 'AWAY_ADV_PACE',
    'HOME_ADV_TS_PCT', 'AWAY_ADV_TS_PCT',
    'HOME_ADV_EFG_PCT', 'AWAY_ADV_EFG_PCT',
    'HOME_ADV_OREB_PCT', 'AWAY_ADV_OREB_PCT',
    'HOME_ADV_DREB_PCT', 'AWAY_ADV_DREB_PCT',
    'HOME_ADV_TM_TOV_PCT', 'AWAY_ADV_TM_TOV_PCT',
    'HOME_ADV_AST_RATIO', 'AWAY_ADV_AST_RATIO',
    'HOME_ADV_PIE', 'AWAY_ADV_PIE',
    'HOME_ADV_OFF_RATING_RANK', 'AWAY_ADV_OFF_RATING_RANK',
    'HOME_ADV_DEF_RATING_RANK', 'AWAY_ADV_DEF_RATING_RANK',
    'HOME_ADV_NET_RATING_RANK', 'AWAY_ADV_NET_RATING_RANK',
    'HOME_ADV_PACE_RANK', 'AWAY_ADV_PACE_RANK',
    'LINE', 'AVG_PACE', 'AVG_OFF_RTG', 'PACE_X_OFF'
]

available = []
missing = []

for feat in required_features:
    if feat in model_df.columns:
        available.append(feat)
    else:
        missing.append(feat)

print(f"✅ Available features: {len(available)}/{len(required_features)}")
if missing:
    print(f"❌ Missing features: {missing[:10]}...")  # Show first 10 missing
else:
    print("✅ All required features are present!")

# Now you can run your model
print("\n" + "="*60)
print("READY TO RUN YOUR MODEL")
print("="*60)
print("\nTo run your model with this data:")
print("  from your_model_file import main_multioutput")
print("  model, features, train_data, X_test, y_test, test_df, results = main_multioutput(model_df)")

# Optionally, create rolling features if you want them now
def create_rolling_features_for_model(df, window_sizes=[5, 10, 20]):
    """
    Create rolling averages for recent form (your function from the original code)
    """
    print("\nCreating rolling features...")
    df = df.copy()

    # For each team, calculate rolling averages
    all_teams = pd.concat([df['HOME_TEAM'], df['AWAY_TEAM']]).unique()

    for team in all_teams:
        team_mask = (df['HOME_TEAM'] == team) | (df['AWAY_TEAM'] == team)
        team_indices = df[team_mask].index.tolist()

        if len(team_indices) < 2:
            continue

        for window in window_sizes:
            for metric in ['OFF_RATING', 'DEF_RATING', 'NET_RATING', 'PACE', 'TS_PCT']:
                rolling_col = f'ROLL_{window}_{metric}'
                if rolling_col not in df.columns:
                    df[rolling_col] = np.nan

                for i, idx in enumerate(team_indices):
                    if i < window:
                        continue

                    prev_indices = team_indices[max(0, i-window):i]
                    values = []

                    for prev_idx in prev_indices:
                        if df.loc[prev_idx, 'HOME_TEAM'] == team:
                            if f'HOME_ADV_{metric}' in df.columns:
                                values.append(df.loc[prev_idx, f'HOME_ADV_{metric}'])
                        else:
                            if f'AWAY_ADV_{metric}' in df.columns:
                                values.append(df.loc[prev_idx, f'AWAY_ADV_{metric}'])

                    if values:
                        df.loc[idx, rolling_col] = np.mean(values)

    return df

# Create rolling features if you want
create_rollings = input("\nCreate rolling features? (y/n): ").lower() == 'y'
if create_rollings:
    model_df = create_rolling_features_for_model(model_df)
    print(f"Added rolling features. Total columns now: {len(model_df.columns)}")

print("\nDone! Your data is ready for the model.")
# Out:
# Fetching game log data...
# Raw data shape: (1750, 29)
# Games in dataset: 875 (each game appears twice)
#
# Fetching team advanced stats...
# Team advanced stats shape: (30, 46)
# Advanced stats columns: ['OFF_RATING', 'DEF_RATING', 'NET_RATING', 'AST_RATIO', 'OREB_PCT', 'DREB_PCT', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT', 'PACE', 'PIE']
#
# ============================================================
# PROCESSING DATA FOR YOUR MODEL
# ============================================================
#
# Processing games into model format...
# Found 875 unique games
#   Processing game 0/875...
#   Processing game 50/875...
#   Processing game 100/875...
#   Processing game 150/875...
#   Processing game 200/875...
#   Processing game 250/875...
#   Processing game 300/875...
#   Processing game 350/875...
#   Processing game 400/875...
#   Processing game 450/875...
#   Processing game 500/875...
#   Processing game 550/875...
#   Processing game 600/875...
#   Processing game 650/875...
#   Processing game 700/875...
#   Processing game 750/875...
#   Processing game 800/875...
#   Processing game 850/875...
#
# Adding derived features...
#
# ✅ Saved processed data to nba_model_data_2025_26.csv
#
# ============================================================
# DATA SUMMARY
# ============================================================
# Total games: 875
# Date range: 2025-10-21 00:00:00 to 2026-02-25 00:00:00
# Number of columns: 53
#
# Sample data (first 5 games):
#    GAME_DATE              HOME_TEAM              AWAY_TEAM  HOME_PTS  AWAY_PTS  HOME_ADV_OFF_RATING  AWAY_ADV_OFF_RATING   LINE
# 0 2025-10-21     Los Angeles Lakers  Golden State Warriors       109       119                116.0                114.5  218.6
# 1 2025-10-21  Oklahoma City Thunder        Houston Rockets       125       124                117.6                117.1  222.8
# 2 2025-10-22       Dallas Mavericks      San Antonio Spurs        92       125                110.6                117.0  215.2
# 3 2025-10-22        Milwaukee Bucks     Washington Wizards       133       120                113.6                109.3  223.8
# 4 2025-10-22          Atlanta Hawks        Toronto Raptors       118       138                113.3                113.5  218.6
#
# ============================================================
# FEATURE AVAILABILITY CHECK
# ============================================================
# ✅ Available features: 34/34
# ✅ All required features are present!
#
# ============================================================
# READY TO RUN YOUR MODEL
# ============================================================
#
# To run your model with this data:
#   from your_model_file import main_multioutput
#   model, features, train_data, X_test, y_test, test_df, results = main_multioutput(model_df)
#
# Create rolling features? (y/n): y
#
# Creating rolling features...
# Added rolling features. Total columns now: 68
#
# Done! Your data is ready for the model.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, VotingRegressor
from sklearn.multioutput import MultiOutputRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
import json
from datetime import datetime

# ============================================================================
# PART 1: YOUR ORIGINAL MODEL CODE (copy this entire section)
# ============================================================================

# 1. Enhanced Feature Set using your actual columns
FEATURES_REG = [
    # Core advanced stats (already calculated in your data)
    'HOME_ADV_OFF_RATING', 'AWAY_ADV_OFF_RATING',
    'HOME_ADV_DEF_RATING', 'AWAY_ADV_DEF_RATING',
    'HOME_ADV_NET_RATING', 'AWAY_ADV_NET_RATING',
    'HOME_ADV_PACE', 'AWAY_ADV_PACE',
    'HOME_ADV_TS_PCT', 'AWAY_ADV_TS_PCT',
    'HOME_ADV_EFG_PCT', 'AWAY_ADV_EFG_PCT',
    'HOME_ADV_OREB_PCT', 'AWAY_ADV_OREB_PCT',
    'HOME_ADV_DREB_PCT', 'AWAY_ADV_DREB_PCT',
    'HOME_ADV_TM_TOV_PCT', 'AWAY_ADV_TM_TOV_PCT',
    'HOME_ADV_AST_RATIO', 'AWAY_ADV_AST_RATIO',
    'HOME_ADV_PIE', 'AWAY_ADV_PIE',

    # Rankings (captures relative strength)
    'HOME_ADV_OFF_RATING_RANK', 'AWAY_ADV_OFF_RATING_RANK',
    'HOME_ADV_DEF_RATING_RANK', 'AWAY_ADV_DEF_RATING_RANK',
    'HOME_ADV_NET_RATING_RANK', 'AWAY_ADV_NET_RATING_RANK',
    'HOME_ADV_PACE_RANK', 'AWAY_ADV_PACE_RANK',

    # Interaction features (pace-of-play matchup)
    'AVG_PACE',
    'AVG_OFF_RTG',
    'PACE_X_OFF',

    # Game context
    'LINE',  # The betting line - very important!
]

def create_rolling_features(df, window_sizes=[5, 10, 20]):
    """
    Create rolling averages for recent form using your existing advanced stats
    """
    df = df.copy()

    # Ensure chronological order
    df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
    df = df.sort_values('GAME_DATE').reset_index(drop=True)

    # For each team, calculate rolling averages of their advanced stats
    all_teams = pd.concat([df['HOME_TEAM'], df['AWAY_TEAM']]).unique()

    for team in all_teams:
        # Get all games for this team (home or away)
        team_mask = (df['HOME_TEAM'] == team) | (df['AWAY_TEAM'] == team)
        team_indices = df[team_mask].index.tolist()

        if len(team_indices) < 2:
            continue

        # For each window size
        for window in window_sizes:
            # Calculate rolling averages for key metrics
            for metric in ['OFF_RATING', 'DEF_RATING', 'NET_RATING', 'PACE', 'TS_PCT']:
                rolling_col = f'ROLL_{window}_{metric}'
                if rolling_col not in df.columns:
                    df[rolling_col] = np.nan

                # For each game involving this team
                for i, idx in enumerate(team_indices):
                    if i < window:  # Not enough previous games
                        continue

                    # Get previous 'window' games
                    prev_indices = team_indices[max(0, i-window):i]

                    # Calculate average of the metric from previous games
                    values = []
                    for prev_idx in prev_indices:
                        if df.loc[prev_idx, 'HOME_TEAM'] == team:
                            if f'HOME_ADV_{metric}' in df.columns:
                                values.append(df.loc[prev_idx, f'HOME_ADV_{metric}'])
                        else:
                            if f'AWAY_ADV_{metric}' in df.columns:
                                values.append(df.loc[prev_idx, f'AWAY_ADV_{metric}'])

                    if values:
                        df.loc[idx, rolling_col] = np.mean(values)

    return df

def create_matchup_features(df):
    """
    Create features specific to the matchup
    """
    df = df.copy()

    # Pace matchup (how styles clash)
    df['PACE_DIFF'] = abs(df['HOME_ADV_PACE'] - df['AWAY_ADV_PACE'])

    # Offensive vs Defensive matchup
    df['OFF_VS_DEF'] = df['HOME_ADV_OFF_RATING'] - df['AWAY_ADV_DEF_RATING']
    df['DEF_VS_OFF'] = df['HOME_ADV_DEF_RATING'] - df['AWAY_ADV_OFF_RATING']

    # Strength indicators
    df['HOME_STRENGTH'] = df['HOME_ADV_NET_RATING'] / 100
    df['AWAY_STRENGTH'] = df['AWAY_ADV_NET_RATING'] / 100
    df['STRENGTH_DIFF'] = df['HOME_STRENGTH'] - df['AWAY_STRENGTH']

    # Shooting efficiency clash
    df['TS_PCT_DIFF'] = df['HOME_ADV_TS_PCT'] - df['AWAY_ADV_TS_PCT']

    # Rebounding battle
    df['REB_BATTLE'] = df['HOME_ADV_OREB_PCT'] + df['HOME_ADV_DREB_PCT'] - \
                       (df['AWAY_ADV_OREB_PCT'] + df['AWAY_ADV_DREB_PCT'])

    # Turnover battle
    df['TOV_BATTLE'] = df['AWAY_ADV_TM_TOV_PCT'] - df['HOME_ADV_TM_TOV_PCT']

    # Home court advantage indicators
    df['HOME_OFF_ADV'] = df['HOME_ADV_OFF_RATING'] - df['AWAY_ADV_OFF_RATING']
    df['HOME_DEF_ADV'] = df['AWAY_ADV_DEF_RATING'] - df['HOME_ADV_DEF_RATING']  # Lower DEF rating is better

    return df

def prepare_multioutput_data(df, features, test_size=0.2):
    """
    Prepare data for multi-output prediction (HOME_PTS, AWAY_PTS, TOTAL_PTS)
    """
    # Sort by date
    df = df.sort_values('GAME_DATE').reset_index(drop=True)

    # Drop rows with missing targets
    df = df.dropna(subset=['HOME_PTS', 'AWAY_PTS', 'TOTAL_PTS'])

    # Select available features
    available_features = [f for f in features if f in df.columns]
    missing = set(features) - set(available_features)
    if missing:
        print(f"Note: Missing features that will be created: {missing}")

    # Create additional features
    print("Creating rolling features...")
    df = create_rolling_features(df)

    print("Creating matchup features...")
    df = create_matchup_features(df)

    # Update available features with newly created ones
    all_features = available_features + [
        'PACE_DIFF', 'OFF_VS_DEF', 'DEF_VS_OFF',
        'HOME_STRENGTH', 'AWAY_STRENGTH', 'STRENGTH_DIFF',
        'TS_PCT_DIFF', 'REB_BATTLE', 'TOV_BATTLE',
        'HOME_OFF_ADV', 'HOME_DEF_ADV'
    ]

    # Add rolling features that exist
    rolling_features = [col for col in df.columns if col.startswith('ROLL_')]
    all_features.extend(rolling_features)

    # Keep only features that exist in df
    final_features = [f for f in all_features if f in df.columns]

    # Drop rows with missing features
    clean_df = df.dropna(subset=final_features + ['HOME_PTS', 'AWAY_PTS', 'TOTAL_PTS']).copy()

    print(f"Total games with complete data: {len(clean_df)}")

    # Time-based split
    split_idx = int(len(clean_df) * (1 - test_size))
    train_df = clean_df.iloc[:split_idx]
    test_df = clean_df.iloc[split_idx:]

    # Features
    X_train = train_df[final_features]
    X_test = test_df[final_features]

    # Multiple targets
    y_train = train_df[['HOME_PTS', 'AWAY_PTS', 'TOTAL_PTS']]
    y_test = test_df[['HOME_PTS', 'AWAY_PTS', 'TOTAL_PTS']]

    print(f"\nTraining on {len(X_train)} games ({train_df['GAME_DATE'].min().date()} to {train_df['GAME_DATE'].max().date()})")
    print(f"Testing on {len(X_test)} games ({test_df['GAME_DATE'].min().date()} to {test_df['GAME_DATE'].max().date()})")
    print(f"Using {len(final_features)} features")
    print(f"Predicting: HOME_PTS, AWAY_PTS, TOTAL_PTS")

    return X_train, X_test, y_train, y_test, final_features, train_df, test_df

def train_multioutput_ensemble(X_train, X_test, y_train, y_test, feature_names, test_df):
    """
    Train multi-output ensemble models for team scores and total
    """
    # Initialize base models
    xgb_base = XGBRegressor(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=5,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        eval_metric='mae'
    )

    cat_base = CatBoostRegressor(
        iterations=300,
        learning_rate=0.05,
        depth=6,
        l2_leaf_reg=3,
        random_seed=42,
        verbose=0,
        loss_function='MAE'
    )

    rf_base = RandomForestRegressor(
        n_estimators=200,
        max_depth=12,
        min_samples_split=10,
        min_samples_leaf=5,
        random_state=42,
        n_jobs=-1
    )

    # Create multi-output models
    print("\nTraining Multi-Output Models...")

    print("Training XGBoost Multi-Output...")
    xgb_multi = MultiOutputRegressor(xgb_base, n_jobs=-1)
    xgb_multi.fit(X_train, y_train)

    print("Training CatBoost Multi-Output...")
    cat_multi = MultiOutputRegressor(cat_base, n_jobs=-1)
    cat_multi.fit(X_train, y_train)

    print("Training Random Forest Multi-Output...")
    rf_multi = MultiOutputRegressor(rf_base, n_jobs=-1)
    rf_multi.fit(X_train, y_train)

    # Create ensemble for each target
    print("\nCreating Ensembles for each target...")

    # For each target, create a voting ensemble
    ensembles = {}
    target_names = ['HOME_PTS', 'AWAY_PTS', 'TOTAL_PTS']

    for i, target in enumerate(target_names):
        ensemble = VotingRegressor([
            ('xgb', xgb_multi.estimators_[i]),
            ('cat', cat_multi.estimators_[i]),
            ('rf', rf_multi.estimators_[i])
        ])
        ensemble.fit(X_train, y_train.iloc[:, i])
        ensembles[target] = ensemble

    # Also create a combined model that predicts all three at once
    # This will be useful for predictions
    combined_model = {
        'ensembles': ensembles,
        'xgb_multi': xgb_multi,
        'cat_multi': cat_multi,
        'rf_multi': rf_multi,
        'feature_names': feature_names,
        'target_names': target_names
    }

    # Evaluate performance
    results_df = evaluate_multioutput_models(combined_model, X_test, y_test, test_df)

    return combined_model, results_df

def evaluate_multioutput_models(model, X_test, y_test, test_df):
    """
    Evaluate multi-output model performance
    """
    print("\n" + "="*60)
    print("MULTI-OUTPUT MODEL PERFORMANCE")
    print("="*60)

    target_names = ['HOME_PTS', 'AWAY_PTS', 'TOTAL_PTS']

    # Get predictions from ensembles
    predictions = {}
    for target in target_names:
        predictions[target] = model['ensembles'][target].predict(X_test)

    # Create results dataframe
    results_df = pd.DataFrame({
        'date': test_df['GAME_DATE'].values,
        'home_team': test_df['HOME_TEAM'].values,
        'away_team': test_df['AWAY_TEAM'].values,
        'home_actual': y_test['HOME_PTS'].values,
        'away_actual': y_test['AWAY_PTS'].values,
        'total_actual': y_test['TOTAL_PTS'].values,
        'home_pred': predictions['HOME_PTS'],
        'away_pred': predictions['AWAY_PTS'],
        'total_pred': predictions['TOTAL_PTS'],
    })

    # Add LINE if available
    if 'LINE' in test_df.columns:
        results_df['line'] = test_df['LINE'].values

    # Calculate errors
    for col in ['home', 'away', 'total']:
        actual = f'{col}_actual'
        pred = f'{col}_pred'
        results_df[f'{col}_error'] = results_df[pred] - results_df[actual]
        results_df[f'{col}_abs_error'] = abs(results_df[pred] - results_df[actual])

    # Print metrics for each target
    for target in target_names:
        target_lower = target.lower().replace('_pts', '')
        mae = results_df[f'{target_lower}_abs_error'].mean()
        rmse = np.sqrt((results_df[f'{target_lower}_error']**2).mean())
        bias = results_df[f'{target_lower}_error'].mean()

        print(f"\n{target}:")
        print(f"  MAE: {mae:.2f} points")
        print(f"  RMSE: {rmse:.2f} points")
        print(f"  Bias: {bias:.2f} points")

    # Total points specific metrics
    print(f"\n{'='*60}")
    print("TOTAL POINTS BETTING METRICS")
    print(f"{'='*60}")

    if 'line' in results_df.columns:
        results_df['total_vs_line'] = results_df['total_pred'] - results_df['line']
        results_df['actual_vs_line'] = results_df['total_actual'] - results_df['line']
        results_df['correct_side'] = ((results_df['total_pred'] > results_df['line']) ==
                                      (results_df['total_actual'] > results_df['line']))

        accuracy = results_df['correct_side'].mean() * 100
        print(f"Over/Under Accuracy: {accuracy:.1f}%")

        # Calculate ROI (assuming -110 odds)
        wins = results_df['correct_side'].sum()
        losses = len(results_df) - wins
        roi = (wins * 0.91 - losses) / len(results_df) * 100
        print(f"ROI (at -110): {roi:.1f}%")

    # Accuracy at different thresholds for total
    for threshold in [5, 10, 15, 20]:
        pct_within = (results_df['total_abs_error'] <= threshold).mean() * 100
        print(f"Total within {threshold} points: {pct_within:.1f}%")

    # Show distribution of errors
    print(f"\nError Distribution:")
    print(f"  Home Mean Error: {results_df['home_error'].mean():.2f}")
    print(f"  Away Mean Error: {results_df['away_error'].mean():.2f}")
    print(f"  Total Mean Error: {results_df['total_error'].mean():.2f}")

    # Show correlation between predictions
    print(f"\n{'='*60}")
    print("PREDICTION CORRELATIONS")
    print(f"{'='*60}")

    corr_home_actual = np.corrcoef(results_df['home_actual'], results_df['home_pred'])[0, 1]
    corr_away_actual = np.corrcoef(results_df['away_actual'], results_df['away_pred'])[0, 1]
    corr_total_actual = np.corrcoef(results_df['total_actual'], results_df['total_pred'])[0, 1]

    print(f"Home Score Correlation: {corr_home_actual:.3f}")
    print(f"Away Score Correlation: {corr_away_actual:.3f}")
    print(f"Total Score Correlation: {corr_total_actual:.3f}")

    # Check consistency (home + away should equal total)
    results_df['calculated_total'] = results_df['home_pred'] + results_df['away_pred']
    results_df['total_diff'] = abs(results_df['calculated_total'] - results_df['total_pred'])
    avg_diff = results_df['total_diff'].mean()
    max_diff = results_df['total_diff'].max()

    print(f"\n{'='*60}")
    print("PREDICTION CONSISTENCY CHECK")
    print(f"{'='*60}")
    print(f"Average difference (home+away vs total): {avg_diff:.4f} points")
    print(f"Maximum difference: {max_diff:.4f} points")
    print(f"Models are {'consistent' if avg_diff < 0.1 else 'slightly inconsistent'}")

    return results_df

def predict_game_multioutput(model, home_team, away_team, line, recent_games_df, feature_names):
    """
    Make multi-output prediction for a new game (home, away, and total)
    """
    # Get most recent game for both teams to get their current stats
    home_games = recent_games_df[
        (recent_games_df['HOME_TEAM'] == home_team) |
        (recent_games_df['AWAY_TEAM'] == home_team)
    ]

    away_games = recent_games_df[
        (recent_games_df['HOME_TEAM'] == away_team) |
        (recent_games_df['AWAY_TEAM'] == away_team)
    ]

    if len(home_games) == 0 or len(away_games) == 0:
        return {"error": f"Team not found in database: {home_team if len(home_games)==0 else away_team}"}

    home_recent = home_games.iloc[-1:]
    away_recent = away_games.iloc[-1:]

    # Build feature dictionary
    features = {}

    # Basic stats
    for prefix in ['HOME_ADV_', 'AWAY_ADV_']:
        for stat in ['OFF_RATING', 'DEF_RATING', 'NET_RATING', 'PACE',
                     'TS_PCT', 'EFG_PCT', 'OREB_PCT', 'DREB_PCT',
                     'TM_TOV_PCT', 'AST_RATIO', 'PIE']:
            col = f"{prefix}{stat}"
            if col in home_recent.columns and prefix == 'HOME_ADV_':
                features[col] = home_recent[col].values[0]
            elif col in away_recent.columns and prefix == 'AWAY_ADV_':
                features[col] = away_recent[col].values[0]
            else:
                # Fill with reasonable defaults if missing
                if 'OFF_RATING' in stat:
                    features[col] = 110.0
                elif 'DEF_RATING' in stat:
                    features[col] = 110.0
                elif 'PACE' in stat:
                    features[col] = 100.0
                elif 'PCT' in stat:
                    features[col] = 0.5
                else:
                    features[col] = 0.0

    # Rankings
    for prefix in ['HOME_ADV_', 'AWAY_ADV_']:
        for stat in ['OFF_RATING_RANK', 'DEF_RATING_RANK', 'NET_RATING_RANK', 'PACE_RANK']:
            col = f"{prefix}{stat}"
            if col in home_recent.columns and prefix == 'HOME_ADV_':
                features[col] = home_recent[col].values[0]
            elif col in away_recent.columns and prefix == 'AWAY_ADV_':
                features[col] = away_recent[col].values[0]
            else:
                features[col] = 15  # Middle rank

    # Game context
    features['LINE'] = line
    features['AVG_PACE'] = (features.get('HOME_ADV_PACE', 100) + features.get('AWAY_ADV_PACE', 100)) / 2
    features['AVG_OFF_RTG'] = (features.get('HOME_ADV_OFF_RATING', 110) + features.get('AWAY_ADV_OFF_RATING', 110)) / 2
    features['PACE_X_OFF'] = features['AVG_PACE'] * features['AVG_OFF_RTG'] / 100

    # Create matchup features
    features['PACE_DIFF'] = abs(features.get('HOME_ADV_PACE', 100) - features.get('AWAY_ADV_PACE', 100))
    features['OFF_VS_DEF'] = features.get('HOME_ADV_OFF_RATING', 110) - features.get('AWAY_ADV_DEF_RATING', 110)
    features['DEF_VS_OFF'] = features.get('HOME_ADV_DEF_RATING', 110) - features.get('AWAY_ADV_OFF_RATING', 110)
    features['HOME_STRENGTH'] = features.get('HOME_ADV_NET_RATING', 0) / 100
    features['AWAY_STRENGTH'] = features.get('AWAY_ADV_NET_RATING', 0) / 100
    features['STRENGTH_DIFF'] = features['HOME_STRENGTH'] - features['AWAY_STRENGTH']
    features['TS_PCT_DIFF'] = features.get('HOME_ADV_TS_PCT', 0.55) - features.get('AWAY_ADV_TS_PCT', 0.55)
    features['HOME_OFF_ADV'] = features.get('HOME_ADV_OFF_RATING', 110) - features.get('AWAY_ADV_OFF_RATING', 110)
    features['HOME_DEF_ADV'] = features.get('AWAY_ADV_DEF_RATING', 110) - features.get('HOME_ADV_DEF_RATING', 110)

    # Rolling features - try to get from recent games
    for col in recent_games_df.columns:
        if col.startswith('ROLL_') and col in feature_names:
            if col in home_recent.columns:
                features[col] = home_recent[col].values[0]
            elif col in away_recent.columns:
                features[col] = away_recent[col].values[0]
            else:
                features[col] = 0

    # Create dataframe with all features
    X_pred = pd.DataFrame([features])

    # Ensure all feature columns exist
    for col in feature_names:
        if col not in X_pred.columns:
            X_pred[col] = 0  # Fill missing with 0

    # Select only the features used in training
    X_pred = X_pred[feature_names]

    # Make predictions using each ensemble
    home_pred = model['ensembles']['HOME_PTS'].predict(X_pred)[0]
    away_pred = model['ensembles']['AWAY_PTS'].predict(X_pred)[0]
    total_pred = model['ensembles']['TOTAL_PTS'].predict(X_pred)[0]

    # Also get individual model predictions for confidence
    individual_preds = {
        'home': {},
        'away': {},
        'total': {}
    }

    for target in ['HOME_PTS', 'AWAY_PTS', 'TOTAL_PTS']:
        for name in ['xgb', 'cat', 'rf']:
            if target == 'HOME_PTS':
                individual_preds['home'][name] = model['ensembles'][target].named_estimators_[name].predict(X_pred)[0]
            elif target == 'AWAY_PTS':
                individual_preds['away'][name] = model['ensembles'][target].named_estimators_[name].predict(X_pred)[0]
            else:
                individual_preds['total'][name] = model['ensembles'][target].named_estimators_[name].predict(X_pred)[0]

    # Calculate confidence based on ensemble agreement
    home_agreement = 1 - (np.std(list(individual_preds['home'].values())) / (np.mean(list(individual_preds['home'].values())) + 1e-10))
    away_agreement = 1 - (np.std(list(individual_preds['away'].values())) / (np.mean(list(individual_preds['away'].values())) + 1e-10))
    total_agreement = 1 - (np.std(list(individual_preds['total'].values())) / (np.mean(list(individual_preds['total'].values())) + 1e-10))

    home_confidence = min(100, max(0, home_agreement * 100))
    away_confidence = min(100, max(0, away_agreement * 100))
    total_confidence = min(100, max(0, total_agreement * 100))

    return {
        'matchup': f"{away_team} @ {home_team}",
        'line': line,
        'predictions': {
            'home': {
                'team': home_team,
                'predicted': round(home_pred, 2),
                'confidence': round(home_confidence, 1),
                'individual': {k: round(v, 2) for k, v in individual_preds['home'].items()}
            },
            'away': {
                'team': away_team,
                'predicted': round(away_pred, 2),
                'confidence': round(away_confidence, 1),
                'individual': {k: round(v, 2) for k, v in individual_preds['away'].items()}
            },
            'total': {
                'predicted': round(total_pred, 2),
                'difference': round(total_pred - line, 2),
                'recommendation': 'OVER' if total_pred > line else 'UNDER',
                'confidence': round(total_confidence, 1),
                'individual': {k: round(v, 2) for k, v in individual_preds['total'].items()}
            }
        },
        'implied_total': round(home_pred + away_pred, 2),
        'verification': abs(round(home_pred + away_pred, 2) - round(total_pred, 2)) < 0.1  # Should be True
    }

def main_multioutput(df):
    """
    Main function to run the multi-output prediction pipeline
    """
    print("="*60)
    print("NBA MULTI-OUTPUT PREDICTION MODEL")
    print("(Home Points, Away Points, Total Points)")
    print("="*60)

    # Prepare data
    X_train, X_test, y_train, y_test, features, train_df, test_df = prepare_multioutput_data(
        df, FEATURES_REG, test_size=0.2
    )

    # Train model - FIXED: passing test_df as parameter
    model, results_df = train_multioutput_ensemble(X_train, X_test, y_train, y_test, features, test_df)

    return model, features, train_df, X_test, y_test, test_df, results_df

# ============================================================================
# PART 2: LOAD YOUR DATA (from the previous step)
# ============================================================================

# Load the data you saved earlier
model_df = pd.read_csv('nba_model_data_2025_26.csv')
model_df['GAME_DATE'] = pd.to_datetime(model_df['GAME_DATE'])

print(f"Loaded {len(model_df)} games from 2025-26 season")

# ============================================================================
# PART 3: RUN THE MODEL
# ============================================================================

# Run your model with the data
model, features, train_data, X_test, y_test, test_df, results = main_multioutput(model_df)

# ============================================================================
# PART 4: MAKE PREDICTIONS
# ============================================================================

# Make a prediction for a specific game
result = predict_game_multioutput(
    model,
    "Los Angeles Lakers",
    "Boston Celtics",
    225.5,
    train_data,
    features
)

# Print the result
def json_serializable(obj):
    if isinstance(obj, (np.floating, np.complexfloating)): return float(obj)
    if isinstance(obj, np.integer): return int(obj)
    if isinstance(obj, (np.bool_, bool)): return bool(obj)
    return str(obj)

print(json.dumps(result, indent=2, default=json_serializable))

# View top 10 test results
print("\nTop 10 Test Results:")
print(results[['date', 'home_team', 'away_team', 'home_actual', 'home_pred',
               'away_actual', 'away_pred', 'total_actual', 'total_pred', 'correct_side']].head(10))
# Out:
# Loaded 875 games from 2025-26 season
# ============================================================
# NBA MULTI-OUTPUT PREDICTION MODEL
# (Home Points, Away Points, Total Points)
# ============================================================
# Creating rolling features...
# Creating matchup features...
# Total games with complete data: 584
#
# Training on 467 games (2025-11-29 to 2026-02-04)
# Testing on 117 games (2026-02-04 to 2026-02-25)
# Using 60 features
# Predicting: HOME_PTS, AWAY_PTS, TOTAL_PTS
#
# Training Multi-Output Models...
# Training XGBoost Multi-Output...
# Training CatBoost Multi-Output...
# Training Random Forest Multi-Output...
#
# Creating Ensembles for each target...
#
# ============================================================
# MULTI-OUTPUT MODEL PERFORMANCE
# ============================================================
#
# HOME_PTS:
#   MAE: 9.41 points
#   RMSE: 12.19 points
#   Bias: 1.88 points
#
# AWAY_PTS:
#   MAE: 9.52 points
#   RMSE: 12.48 points
#   Bias: -1.14 points
#
# TOTAL_PTS:
#   MAE: 14.57 points
#   RMSE: 19.05 points
#   Bias: 0.79 points
#
# ============================================================
# TOTAL POINTS BETTING METRICS
# ============================================================
# Over/Under Accuracy: 71.8%
# ROI (at -110): 37.1%
# Total within 5 points: 27.4%
# Total within 10 points: 42.7%
# Total within 15 points: 59.0%
# Total within 20 points: 73.5%
#
# Error Distribution:
#   Home Mean Error: 1.88
#   Away Mean Error: -1.14
#   Total Mean Error: 0.79
#
# ============================================================
# PREDICTION CORRELATIONS
# ============================================================
# Home Score Correlation: 0.314
# Away Score Correlation: 0.381
# Total Score Correlation: 0.285
#
# ============================================================
# PREDICTION CONSISTENCY CHECK
# ============================================================
# Average difference (home+away vs total): 1.9284 points
# Maximum difference: 6.7090 points
# Models are slightly inconsistent
# {
#   "matchup": "Boston Celtics @ Los Angeles Lakers",
#   "line": 225.5,
#   "predictions": {
#     "home": {
#       "team": "Los Angeles Lakers",
#       "predicted": 114.67,
#       "confidence": 98.3,
#       "individual": {
#         "xgb": 117.18000030517578,
#         "cat": 114.29,
#         "rf": 112.53
#       }
#     },
#     "away": {
#       "team": "Boston Celtics",
#       "predicted": 120.19,
#       "confidence": 97.1,
#       "individual": {
#         "xgb": 121.4800033569336,
#         "cat": 123.69,
#         "rf": 115.4
#       }
#     },
#     "total": {
#       "predicted": 232.44,
#       "difference": 6.94,
#       "recommendation": "OVER",
#       "confidence": 98.6,
#       "individual": {
#         "xgb": 237.08999633789062,
#         "cat": 229.41,
#         "rf": 230.81
#       }
#     }
#   },
#   "implied_total": 234.86,
#   "verification": false
# }
#
# Top 10 Test Results:
#         date           home_team              away_team  home_actual  \
# 0 2026-02-04         LA Clippers    Cleveland Cavaliers           91
# 1 2026-02-04    Sacramento Kings      Memphis Grizzlies          125
# 2 2026-02-05     Detroit Pistons     Washington Wizards          117
# 3 2026-02-05  Los Angeles Lakers     Philadelphia 76ers          119
# 4 2026-02-05        Phoenix Suns  Golden State Warriors           97
# 5 2026-02-05       Orlando Magic          Brooklyn Nets          118
# 6 2026-02-05     Houston Rockets      Charlotte Hornets           99
# 7 2026-02-05       Atlanta Hawks              Utah Jazz          121
# 8 2026-02-05     Toronto Raptors          Chicago Bulls          123
# 9 2026-02-05    Dallas Mavericks      San Antonio Spurs          123
#
#     home_pred  away_actual   away_pred  total_actual  total_pred  correct_side
# 0  111.737204          124  114.965247           215  227.604951         False
# 1  107.248232          129  113.754700           254  221.379671          True
# 2  121.049216          126  104.134662           243  222.581296         False
# 3  113.658000          115  116.938476           234  226.770254          True
# 4  107.139412          101  105.148900           198  211.344774          True
# 5  115.836628           98  103.108382           216  216.348301          True
# 6  108.055273          109  104.505125           208  208.360428          True
# 7  133.701867          119  121.802003           240  256.262813          True
# 8  119.041631          107  110.290206           230  227.378942          True
# 9  114.828230          135  119.181612           258  233.439980          True

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from nba_api.stats.endpoints import leaguegamelog, leaguedashteamstats
from nba_api.stats.static import teams
import time
import json

class NBARealTimePredictor:
    """
    Real-time NBA game predictor using your trained model
    """

    def __init__(self, model, feature_names, trained_model_data):
        """
        Initialize with your trained model

        Args:
            model: Your trained model from main_multioutput
            feature_names: List of feature names used by the model
            trained_model_data: The training dataframe (for reference)
        """
        self.model = model
        self.feature_names = feature_names
        self.trained_model_data = trained_model_data
        self.team_name_map = self._create_team_name_map()

    def _create_team_name_map(self):
        """Create mapping from various team name formats to standard names"""
        # Get all NBA teams
        nba_teams = teams.get_teams()

        # Create mapping dictionary
        team_map = {}
        for team in nba_teams:
            # Map full name
            team_map[team['full_name'].lower()] = team['full_name']
            # Map abbreviation
            team_map[team['abbreviation'].lower()] = team['full_name']
            # Map nickname
            team_map[team['nickname'].lower()] = team['full_name']
            # Map city
            city = team['full_name'].replace(' ' + team['nickname'], '')
            team_map[city.lower()] = team['full_name']

        # Add common variations
        common_variations = {
            'lakers': 'Los Angeles Lakers',
            'celtics': 'Boston Celtics',
            'warriors': 'Golden State Warriors',
            'bulls': 'Chicago Bulls',
            'heat': 'Miami Heat',
            'sixers': 'Philadelphia 76ers',
            '76ers': 'Philadelphia 76ers',
            'knicks': 'New York Knicks',
            'mavericks': 'Dallas Mavericks',
            'mavs': 'Dallas Mavericks',
            'blazers': 'Portland Trail Blazers',
            'trail blazers': 'Portland Trail Blazers',
            'wolves': 'Minnesota Timberwolves',
            'timberwolves': 'Minnesota Timberwolves',
            'thunder': 'Oklahoma City Thunder',
            'okc': 'Oklahoma City Thunder',
            'spurs': 'San Antonio Spurs',
            'rockets': 'Houston Rockets',
            'jazz': 'Utah Jazz',
            'kings': 'Sacramento Kings',
            'suns': 'Phoenix Suns',
            'clippers': 'LA Clippers',
            'lac': 'LA Clippers',
            'nuggets': 'Denver Nuggets',
            'bucks': 'Milwaukee Bucks',
            'pacers': 'Indiana Pacers',
            'magic': 'Orlando Magic',
            'hawks': 'Atlanta Hawks',
            'hornets': 'Charlotte Hornets',
            'pistons': 'Detroit Pistons',
            'cavaliers': 'Cleveland Cavaliers',
            'cavs': 'Cleveland Cavaliers',
            'raptors': 'Toronto Raptors',
            'wizards': 'Washington Wizards',
            'grizzlies': 'Memphis Grizzlies',
            'pelicans': 'New Orleans Pelicans',
            'nola': 'New Orleans Pelicans'
        }
        team_map.update(common_variations)

        return team_map

    def _standardize_team_name(self, team_input):
        """Convert various team name formats to standard name"""
        if not team_input:
            return None

        # If already in correct format and exists in training data
        if team_input in self.trained_model_data['HOME_TEAM'].values:
            return team_input

        # Try to find in mapping
        team_lower = team_input.lower().strip()
        if team_lower in self.team_name_map:
            return self.team_name_map[team_lower]

        # Try partial matching
        for key, value in self.team_name_map.items():
            if key in team_lower or team_lower in key:
                return value

        return team_input  # Return original if no match found

    def fetch_live_team_stats(self, team_name, season="2025-26"):
        """
        Fetch current season stats for a team from NBA API
        """
        try:
            # Get team ID
            nba_teams = teams.get_teams()
            team_id = None
            for team in nba_teams:
                if team['full_name'].lower() == team_name.lower():
                    team_id = team['id']
                    break

            if not team_id:
                print(f"Could not find team ID for {team_name}")
                return None

            # Get team advanced stats
            team_stats = leaguedashteamstats.LeagueDashTeamStats(
                season=season,
                season_type_all_star='Regular Season',
                measure_type_detailed_defense='Advanced',
                per_mode_detailed='PerGame',
                timeout=30
            ).get_data_frames()[0]

            # Get team's stats
            team_row = team_stats[team_stats['TEAM_ID'] == team_id]

            if len(team_row) == 0:
                print(f"No stats found for {team_name}")
                return None

            team_row = team_row.iloc[0]

            # Extract advanced stats
            stats = {}
            advanced_metrics = [
                'OFF_RATING', 'DEF_RATING', 'NET_RATING', 'PACE',
                'TS_PCT', 'EFG_PCT', 'OREB_PCT', 'DREB_PCT',
                'TM_TOV_PCT', 'AST_RATIO', 'PIE'
            ]

            for metric in advanced_metrics:
                stats[metric] = team_row.get(metric, np.nan)

            # Get rankings
            ranking_metrics = ['OFF_RATING', 'DEF_RATING', 'NET_RATING', 'PACE']
            for metric in ranking_metrics:
                stats[f'{metric}_RANK'] = team_row.get(f'{metric}_RANK', np.nan)

            return stats

        except Exception as e:
            print(f"Error fetching stats for {team_name}: {e}")
            return None

    def fetch_recent_games(self, team_name, num_games=10, season="2025-26"):
        """
        Fetch recent games for a team to calculate rolling averages
        """
        try:
            # Get team ID
            nba_teams = teams.get_teams()
            team_id = None
            for team in nba_teams:
                if team['full_name'].lower() == team_name.lower():
                    team_id = team['id']
                    break

            if not team_id:
                print(f"Could not find team ID for {team_name}")
                return pd.DataFrame()

            # Get team game log
            team_games = leaguegamelog.LeagueGameLog(
                season=season,
                season_type_all_star='Regular Season',
                team_id_nullable=team_id,
                timeout=30
            ).get_data_frames()[0]

            # Sort by date (most recent first)
            team_games['GAME_DATE'] = pd.to_datetime(team_games['GAME_DATE'])
            team_games = team_games.sort_values('GAME_DATE', ascending=False)

            # Get last N games
            recent = team_games.head(num_games).copy()

            # Add home/away indicator
            recent['IS_HOME'] = recent['MATCHUP'].str.contains('vs.')

            return recent

        except Exception as e:
            print(f"Error fetching recent games for {team_name}: {e}")
            return pd.DataFrame()

    def calculate_rolling_averages(self, team_name, recent_games_df, window_sizes=[5, 10, 20]):
        """
        Calculate rolling averages from recent games data
        """
        rolling_stats = {}

        # We need advanced stats for these games
        # This is a simplified version - in practice you'd want to fetch
        # advanced stats for each game date

        # For now, we'll use season averages as a fallback
        season_stats = self.fetch_live_team_stats(team_name)
        if not season_stats:
            return rolling_stats

        # Create rolling averages (simplified - using season stats as base)
        # In production, you'd want actual per-game advanced stats
        for window in window_sizes:
            for metric in ['OFF_RATING', 'DEF_RATING', 'NET_RATING', 'PACE', 'TS_PCT']:
                rolling_col = f'ROLL_{window}_{metric}'
                # For simplicity, we'll use season averages
                # In reality, you'd calculate from actual game data
                if metric in season_stats:
                    rolling_stats[rolling_col] = season_stats[metric]

        return rolling_stats

    def prepare_game_features(self, home_team, away_team, line=None):
        """
        Prepare all features needed for prediction
        """
        print(f"\nPreparing features for {away_team} @ {home_team}...")

        # Standardize team names
        home_team = self._standardize_team_name(home_team)
        away_team = self._standardize_team_name(away_team)

        print(f"Standardized: {away_team} @ {home_team}")

        # Fetch current stats for both teams
        home_stats = self.fetch_live_team_stats(home_team)
        away_stats = self.fetch_live_team_stats(away_team)

        if not home_stats or not away_stats:
            print("Failed to fetch team stats")
            return None

        # Fetch recent games for rolling averages
        home_recent = self.fetch_recent_games(home_team, num_games=20)
        away_recent = self.fetch_recent_games(away_team, num_games=20)

        # Calculate rolling averages
        home_rolling = self.calculate_rolling_averages(home_team, home_recent)
        away_rolling = self.calculate_rolling_averages(away_team, away_recent)

        # Build feature dictionary
        features = {}

        # Add basic stats
        for stat, value in home_stats.items():
            features[f'HOME_ADV_{stat}'] = value

        for stat, value in away_stats.items():
            features[f'AWAY_ADV_{stat}'] = value

        # Add rolling features
        features.update(home_rolling)
        features.update(away_rolling)

        # Set line (default if not provided)
        if line is None:
            # Simple line estimate based on net rating difference
            net_diff = home_stats.get('NET_RATING', 0) - away_stats.get('NET_RATING', 0)
            line = 225 + (net_diff * 0.3)  # 225 is average NBA total
            line = round(line, 1)
            print(f"Estimated line: {line}")

        features['LINE'] = line

        # Calculate derived features
        features['AVG_PACE'] = (features.get('HOME_ADV_PACE', 100) + features.get('AWAY_ADV_PACE', 100)) / 2
        features['AVG_OFF_RTG'] = (features.get('HOME_ADV_OFF_RATING', 110) + features.get('AWAY_ADV_OFF_RATING', 110)) / 2
        features['PACE_X_OFF'] = features['AVG_PACE'] * features['AVG_OFF_RTG'] / 100

        # Matchup features
        features['PACE_DIFF'] = abs(features.get('HOME_ADV_PACE', 100) - features.get('AWAY_ADV_PACE', 100))
        features['OFF_VS_DEF'] = features.get('HOME_ADV_OFF_RATING', 110) - features.get('AWAY_ADV_DEF_RATING', 110)
        features['DEF_VS_OFF'] = features.get('HOME_ADV_DEF_RATING', 110) - features.get('AWAY_ADV_OFF_RATING', 110)
        features['HOME_STRENGTH'] = features.get('HOME_ADV_NET_RATING', 0) / 100
        features['AWAY_STRENGTH'] = features.get('AWAY_ADV_NET_RATING', 0) / 100
        features['STRENGTH_DIFF'] = features['HOME_STRENGTH'] - features['AWAY_STRENGTH']
        features['TS_PCT_DIFF'] = features.get('HOME_ADV_TS_PCT', 0.55) - features.get('AWAY_ADV_TS_PCT', 0.55)
        features['HOME_OFF_ADV'] = features.get('HOME_ADV_OFF_RATING', 110) - features.get('AWAY_ADV_OFF_RATING', 110)
        features['HOME_DEF_ADV'] = features.get('AWAY_ADV_DEF_RATING', 110) - features.get('HOME_ADV_DEF_RATING', 110)

        # Rebounding and turnover battles
        features['REB_BATTLE'] = (features.get('HOME_ADV_OREB_PCT', 0.25) + features.get('HOME_ADV_DREB_PCT', 0.75) -
                                  features.get('AWAY_ADV_OREB_PCT', 0.25) - features.get('AWAY_ADV_DREB_PCT', 0.75))
        features['TOV_BATTLE'] = features.get('AWAY_ADV_TM_TOV_PCT', 0.13) - features.get('HOME_ADV_TM_TOV_PCT', 0.13)

        return features

    def predict_game(self, home_team, away_team, line=None):
        """
        Make real-time prediction for a game
        """
        # Prepare features
        features = self.prepare_game_features(home_team, away_team, line)

        if features is None:
            return {"error": "Failed to prepare features"}

        # Create dataframe with features
        X_pred = pd.DataFrame([features])

        # Ensure all feature columns exist
        for col in self.feature_names:
            if col not in X_pred.columns:
                X_pred[col] = 0

        # Select only features used in training
        X_pred = X_pred[self.feature_names]

        # Make prediction using your model
        home_pred = self.model['ensembles']['HOME_PTS'].predict(X_pred)[0]
        away_pred = self.model['ensembles']['AWAY_PTS'].predict(X_pred)[0]
        total_pred = self.model['ensembles']['TOTAL_PTS'].predict(X_pred)[0]

        # Get individual model predictions for confidence
        individual_preds = {'home': {}, 'away': {}, 'total': {}}

        for target in ['HOME_PTS', 'AWAY_PTS', 'TOTAL_PTS']:
            for name in ['xgb', 'cat', 'rf']:
                pred = self.model['ensembles'][target].named_estimators_[name].predict(X_pred)[0]
                if target == 'HOME_PTS':
                    individual_preds['home'][name] = pred
                elif target == 'AWAY_PTS':
                    individual_preds['away'][name] = pred
                else:
                    individual_preds['total'][name] = pred

        # Calculate confidence based on agreement
        home_conf = 1 - (np.std(list(individual_preds['home'].values())) / (np.mean(list(individual_preds['home'].values())) + 1e-10))
        away_conf = 1 - (np.std(list(individual_preds['away'].values())) / (np.mean(list(individual_preds['away'].values())) + 1e-10))
        total_conf = 1 - (np.std(list(individual_preds['total'].values())) / (np.mean(list(individual_preds['total'].values())) + 1e-10))

        # Prepare result
        result = {
            'game_info': {
                'matchup': f"{away_team} @ {home_team}",
                'date': datetime.now().strftime('%Y-%m-%d'),
                'line': features.get('LINE', line),
                'data_source': 'Live NBA API (2025-26 season)'
            },
            'team_stats': {
                'home': {
                    'name': home_team,
                    'off_rating': round(features.get('HOME_ADV_OFF_RATING', 0), 2),
                    'def_rating': round(features.get('HOME_ADV_DEF_RATING', 0), 2),
                    'net_rating': round(features.get('HOME_ADV_NET_RATING', 0), 2),
                    'pace': round(features.get('HOME_ADV_PACE', 0), 2)
                },
                'away': {
                    'name': away_team,
                    'off_rating': round(features.get('AWAY_ADV_OFF_RATING', 0), 2),
                    'def_rating': round(features.get('AWAY_ADV_DEF_RATING', 0), 2),
                    'net_rating': round(features.get('AWAY_ADV_NET_RATING', 0), 2),
                    'pace': round(features.get('AWAY_ADV_PACE', 0), 2)
                }
            },
            'predictions': {
                'home': {
                    'team': home_team,
                    'predicted': round(home_pred, 1),
                    'confidence': round(home_conf * 100, 1),
                    'individual': {k: round(v, 1) for k, v in individual_preds['home'].items()}
                },
                'away': {
                    'team': away_team,
                    'predicted': round(away_pred, 1),
                    'confidence': round(away_conf * 100, 1),
                    'individual': {k: round(v, 1) for k, v in individual_preds['away'].items()}
                },
                'total': {
                    'predicted': round(total_pred, 1),
                    'line': features.get('LINE', line),
                    'difference': round(total_pred - features.get('LINE', line), 1),
                    'recommendation': 'OVER' if total_pred > features.get('LINE', line) else 'UNDER',
                    'confidence': round(total_conf * 100, 1),
                    'individual': {k: round(v, 1) for k, v in individual_preds['total'].items()}
                }
            },
            'implied_total': round(home_pred + away_pred, 1),
            'verification': abs(round(home_pred + away_pred, 1) - round(total_pred, 1)) < 0.1
        }

        return result

    def predict_multiple_games(self, games_list):
        """
        Predict multiple games at once

        Args:
            games_list: List of dicts with keys ['home', 'away', 'line'] (line optional)
        """
        results = []

        for i, game in enumerate(games_list):
            print(f"\n{'='*60}")
            print(f"Game {i+1}/{len(games_list)}")

            result = self.predict_game(
                game['home'],
                game['away'],
                game.get('line')
            )

            results.append(result)

            # Small delay to avoid rate limiting
            time.sleep(1)

        return results

    def print_prediction(self, result):
        """Pretty print a prediction result"""
        if 'error' in result:
            print(f"❌ Error: {result['error']}")
            return

        print("\n" + "="*70)
        print(f"🏀 {result['game_info']['matchup']}")
        print(f"📅 {result['game_info']['date']}")
        print("="*70)

        print("\n📊 TEAM STATS:")
        print(f"  Home - {result['team_stats']['home']['name']}:")
        print(f"    Off: {result['team_stats']['home']['off_rating']} | Def: {result['team_stats']['home']['def_rating']} | Net: {result['team_stats']['home']['net_rating']} | Pace: {result['team_stats']['home']['pace']}")
        print(f"  Away - {result['team_stats']['away']['name']}:")
        print(f"    Off: {result['team_stats']['away']['off_rating']} | Def: {result['team_stats']['away']['def_rating']} | Net: {result['team_stats']['away']['net_rating']} | Pace: {result['team_stats']['away']['pace']}")

        print("\n🎯 PREDICTIONS:")
        print(f"  Home: {result['predictions']['home']['team']} - {result['predictions']['home']['predicted']} pts (Conf: {result['predictions']['home']['confidence']}%)")
        print(f"  Away: {result['predictions']['away']['team']} - {result['predictions']['away']['predicted']} pts (Conf: {result['predictions']['away']['confidence']}%)")
        print(f"  Total: {result['predictions']['total']['predicted']} pts | Line: {result['predictions']['total']['line']}")

        # Color coded recommendation
        diff = result['predictions']['total']['difference']
        rec = result['predictions']['total']['recommendation']
        if diff > 3:
            rec_display = f"🔴 {rec} (Strong)"
        elif diff > 1:
            rec_display = f"🟠 {rec}"
        elif diff > 0:
            rec_display = f"🟡 {rec}"
        elif diff > -1:
            rec_display = f"🟢 UNDER (Lean)"
        else:
            rec_display = f"🔵 UNDER (Strong)"

        print(f"  Recommendation: {rec_display} (Diff: {result['predictions']['total']['difference']:+})")
        print(f"  Confidence: {result['predictions']['total']['confidence']}%")

        print("\n🤖 Model Agreement:")
        print(f"  Home: XGB={result['predictions']['home']['individual']['xgb']} | CAT={result['predictions']['home']['individual']['cat']} | RF={result['predictions']['home']['individual']['rf']}")
        print(f"  Away: XGB={result['predictions']['away']['individual']['xgb']} | CAT={result['predictions']['away']['individual']['cat']} | RF={result['predictions']['away']['individual']['rf']}")
        print(f"  Total: XGB={result['predictions']['total']['individual']['xgb']} | CAT={result['predictions']['total']['individual']['cat']} | RF={result['predictions']['total']['individual']['rf']}")

        print("\n" + "="*70)


# ============================================================================
# USAGE EXAMPLE
# ============================================================================

"""
Assuming you already have your trained model from earlier:

model, features, train_data, X_test, y_test, test_df, results = main_multioutput(model_df)

Now you can create the real-time predictor:
"""

# Initialize the predictor with your trained model
predictor = NBARealTimePredictor(model, features, train_data)

# Example 1: Predict a single game
print("\n" + "="*70)
print("PREDICTING SINGLE GAME")
print("="*70)

result = predictor.predict_game(
    home_team="Los Angeles Lakers",
    away_team="Boston Celtics",
    line=228.5  # Optional - if not provided, will estimate
)

predictor.print_prediction(result)

# Example 2: Predict multiple games (tomorrow's slate)
print("\n" + "="*70)
print("PREDICTING MULTIPLE GAMES")
print("="*70)

tomorrow_games = [
    {"home": "Toronto Raptors", "away": "San Antonio Spurs", "line": 230.5},
    {"home": "Memphis Grizzlies", "away": "Golden State Warriors","line": 224.5},  # Line will be estimated
    {"home": "Detroit Pistons", "away": "Oklahoma City Thunder", "line": 219.5},
    {"home": "Houston Rockets", "away": "Sacramento Kings","line": 222.5},
    {"home": "Milwaukee Bucks", "away": "Cleveland Cavaliers","line": 222.5}
]

results = predictor.predict_multiple_games(tomorrow_games)

# Print all results
for i, result in enumerate(results):
    predictor.print_prediction(result)

# Example 3: Interactive prediction
def interactive_prediction(predictor):
    """Interactive mode to predict games"""
    print("\n" + "="*70)
    print("INTERACTIVE PREDICTION MODE")
    print("="*70)
    print("Enter 'quit' to exit")

    while True:
        print("\n" + "-"*40)
        home = input("Home team: ").strip()
        if home.lower() == 'quit':
            break

        away = input("Away team: ").strip()
        if away.lower() == 'quit':
            break

        line_input = input("Line (optional, press Enter to skip): ").strip()
        line = float(line_input) if line_input else None

        result = predictor.predict_game(home, away, line)
        predictor.print_prediction(result)

# Uncomment to run interactive mode
# interactive_prediction(predictor)

# Example 4: Export predictions to JSON
def export_predictions(predictor, games_list, filename="predictions.json"):
    """Export predictions to JSON file"""
    results = predictor.predict_multiple_games(games_list)

    # Convert to serializable format
    def json_serializable(obj):
        if isinstance(obj, (np.floating, np.complexfloating)): return float(obj)
        if isinstance(obj, np.integer): return int(obj)
        if isinstance(obj, (np.bool_, bool)): return bool(obj)
        return str(obj)

    with open(filename, 'w') as f:
        json.dump(results, f, indent=2, default=json_serializable)

    print(f"\n✅ Predictions exported to {filename}")
    return results

# Export tomorrow's games
# export_predictions(predictor, tomorrow_games, "tomorrow_predictions.json")
# Out:
# ======================================================================
# PREDICTING SINGLE GAME
# ======================================================================
#
# Preparing features for Boston Celtics @ Los Angeles Lakers...
# Standardized: Boston Celtics @ Los Angeles Lakers
# Error fetching recent games for Los Angeles Lakers: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
# Error fetching recent games for Boston Celtics: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
#
# ======================================================================
# 🏀 Boston Celtics @ Los Angeles Lakers
# 📅 2026-02-26
# ======================================================================
#
# 📊 TEAM STATS:
#   Home - Los Angeles Lakers:
#     Off: 116.0 | Def: 116.6 | Net: -0.7 | Pace: 99.54
#   Away - Boston Celtics:
#     Off: 119.5 | Def: 111.9 | Net: 7.6 | Pace: 95.54
#
# 🎯 PREDICTIONS:
#   Home: Los Angeles Lakers - 111.1 pts (Conf: 96.6%)
#   Away: Boston Celtics - 113.3 pts (Conf: 98.8%)
#   Total: 226.1 pts | Line: 228.5
#   Recommendation: 🔵 UNDER (Strong) (Diff: -2.4)
#   Confidence: 99.0%
#
# 🤖 Model Agreement:
#   Home: XGB=115.80000305175781 | CAT=106.6 | RF=110.9
#   Away: XGB=114.9000015258789 | CAT=113.4 | RF=111.5
#   Total: XGB=229.39999389648438 | CAT=224.6 | RF=224.5
#
# ======================================================================
#
# ======================================================================
# PREDICTING MULTIPLE GAMES
# ======================================================================
#
# ============================================================
# Game 1/5
#
# Preparing features for San Antonio Spurs @ Toronto Raptors...
# Standardized: San Antonio Spurs @ Toronto Raptors
# Error fetching recent games for Toronto Raptors: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
# Error fetching recent games for San Antonio Spurs: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
#
# ============================================================
# Game 2/5
#
# Preparing features for Golden State Warriors @ Memphis Grizzlies...
# Standardized: Golden State Warriors @ Memphis Grizzlies
# Error fetching recent games for Memphis Grizzlies: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
# Error fetching recent games for Golden State Warriors: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
#
# ============================================================
# Game 3/5
#
# Preparing features for Oklahoma City Thunder @ Detroit Pistons...
# Standardized: Oklahoma City Thunder @ Detroit Pistons
# Error fetching recent games for Detroit Pistons: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
# Error fetching recent games for Oklahoma City Thunder: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
#
# ============================================================
# Game 4/5
#
# Preparing features for Sacramento Kings @ Houston Rockets...
# Standardized: Sacramento Kings @ Houston Rockets
# Error fetching recent games for Houston Rockets: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
# Error fetching recent games for Sacramento Kings: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
#
# ============================================================
# Game 5/5
#
# Preparing features for Cleveland Cavaliers @ Milwaukee Bucks...
# Standardized: Cleveland Cavaliers @ Milwaukee Bucks
# Error fetching recent games for Milwaukee Bucks: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
# Error fetching recent games for Cleveland Cavaliers: LeagueGameLog.__init__() got an unexpected keyword argument 'team_id_nullable'
#
# ======================================================================
# 🏀 San Antonio Spurs @ Toronto Raptors
# 📅 2026-02-26
# ======================================================================
#
# 📊 TEAM STATS:
#   Home - Toronto Raptors:
#     Off: 113.5 | Def: 111.7 | Net: 1.8 | Pace: 99.38
#   Away - San Antonio Spurs:
#     Off: 117.0 | Def: 110.3 | Net: 6.7 | Pace: 101.02
#
# 🎯 PREDICTIONS:
#   Home: Toronto Raptors - 113.4 pts (Conf: 98.7%)
#   Away: San Antonio Spurs - 115.4 pts (Conf: 99.0%)
#   Total: 229.2 pts | Line: 230.5
#   Recommendation: 🔵 UNDER (Strong) (Diff: -1.3)
#   Confidence: 98.0%
#
# 🤖 Model Agreement:
#   Home: XGB=114.69999694824219 | CAT=111.3 | RF=114.2
#   Away: XGB=116.19999694824219 | CAT=113.7 | RF=116.2
#   Total: XGB=232.5 | CAT=222.6 | RF=232.4
#
# ======================================================================
#
# ======================================================================
# 🏀 Golden State Warriors @ Memphis Grizzlies
# 📅 2026-02-26
# ======================================================================
#
# 📊 TEAM STATS:
#   Home - Memphis Grizzlies:
#     Off: 113.1 | Def: 115.9 | Net: -2.8 | Pace: 101.59
#   Away - Golden State Warriors:
#     Off: 114.5 | Def: 112.5 | Net: 2.0 | Pace: 100.81
#
# 🎯 PREDICTIONS:
#   Home: Memphis Grizzlies - 114.4 pts (Conf: 98.7%)
#   Away: Golden State Warriors - 114.1 pts (Conf: 95.3%)
#   Total: 227.9 pts | Line: 224.5
#   Recommendation: 🔴 OVER (Strong) (Diff: +3.4)
#   Confidence: 98.0%
#
# 🤖 Model Agreement:
#   Home: XGB=115.9000015258789 | CAT=112.4 | RF=115.0
#   Away: XGB=106.69999694824219 | CAT=119.0 | RF=116.7
#   Total: XGB=221.5 | CAT=231.6 | RF=230.6
#
# ======================================================================
#
# ======================================================================
# 🏀 Oklahoma City Thunder @ Detroit Pistons
# 📅 2026-02-26
# ======================================================================
#
# 📊 TEAM STATS:
#   Home - Detroit Pistons:
#     Off: 116.6 | Def: 108.5 | Net: 8.1 | Pace: 100.49
#   Away - Oklahoma City Thunder:
#     Off: 117.6 | Def: 106.4 | Net: 11.2 | Pace: 100.64
#
# 🎯 PREDICTIONS:
#   Home: Detroit Pistons - 110.9 pts (Conf: 97.6%)
#   Away: Oklahoma City Thunder - 111.5 pts (Conf: 99.4%)
#   Total: 228.3 pts | Line: 219.5
#   Recommendation: 🔴 OVER (Strong) (Diff: +8.8)
#   Confidence: 99.3%
#
# 🤖 Model Agreement:
#   Home: XGB=112.5 | CAT=107.2 | RF=113.1
#   Away: XGB=110.80000305175781 | CAT=111.3 | RF=112.4
#   Total: XGB=228.89999389648438 | CAT=226.2 | RF=229.7
#
# ======================================================================
#
# ======================================================================
# 🏀 Sacramento Kings @ Houston Rockets
# 📅 2026-02-26
# ======================================================================
#
# 📊 TEAM STATS:
#   Home - Houston Rockets:
#     Off: 117.1 | Def: 111.4 | Net: 5.6 | Pace: 96.74
#   Away - Sacramento Kings:
#     Off: 109.4 | Def: 120.1 | Net: -10.7 | Pace: 100.2
#
# 🎯 PREDICTIONS:
#   Home: Houston Rockets - 119.2 pts (Conf: 98.5%)
#   Away: Sacramento Kings - 95.1 pts (Conf: 98.9%)
#   Total: 217.3 pts | Line: 222.5
#   Recommendation: 🔵 UNDER (Strong) (Diff: -5.2)
#   Confidence: 99.8%
#
# 🤖 Model Agreement:
#   Home: XGB=120.9000015258789 | CAT=116.8 | RF=119.9
#   Away: XGB=96.5 | CAT=94.1 | RF=94.7
#   Total: XGB=217.6999969482422 | CAT=217.4 | RF=216.8
#
# ======================================================================
#
# ======================================================================
# 🏀 Cleveland Cavaliers @ Milwaukee Bucks
# 📅 2026-02-26
# ======================================================================
#
# 📊 TEAM STATS:
#   Home - Milwaukee Bucks:
#     Off: 113.6 | Def: 116.5 | Net: -2.9 | Pace: 98.44
#   Away - Cleveland Cavaliers:
#     Off: 117.6 | Def: 113.1 | Net: 4.4 | Pace: 101.3
#
# 🎯 PREDICTIONS:
#   Home: Milwaukee Bucks - 116.0 pts (Conf: 98.8%)
#   Away: Cleveland Cavaliers - 118.7 pts (Conf: 99.2%)
#   Total: 239.3 pts | Line: 222.5
#   Recommendation: 🔴 OVER (Strong) (Diff: +16.8)
#   Confidence: 98.9%
#
# 🤖 Model Agreement:
#   Home: XGB=117.80000305175781 | CAT=114.4 | RF=115.7
#   Away: XGB=117.4000015258789 | CAT=119.5 | RF=119.1
#   Total: XGB=242.60000610351562 | CAT=236.2 | RF=239.0
#
# ======================================================================

# %%
import pandas as pd
from nba_api.stats.endpoints import playergamelogs

# Fetch game logs for ALL players for the 2025-26 season
# Note: The season format must be '2025-26'
game_logs = playergamelogs.PlayerGameLogs(
    season_nullable='2025-26',
    season_type_nullable='Regular Season'
)

# Convert the response to a Pandas DataFrame
df = game_logs.get_data_frames()[0]

# Display the first few rows
print(df.head())
# Out:
#   SEASON_YEAR  PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID  \
# 0     2025-26    1630578   Alperen Sengun  Alperen  1610612745
# 1     2025-26    1630595  Cade Cunningham     Cade  1610612765
# 2     2025-26    1631119  Jaylin Williams   Jaylin  1610612760
# 3     2025-26     203999     Nikola Jokić   Nikola  1610612743
# 4     2025-26    1631105      Jalen Duren    Jalen  1610612765
#
#   TEAM_ABBREVIATION              TEAM_NAME     GAME_ID            GAME_DATE  \
# 0               HOU        Houston Rockets  0022500845  2026-02-25T00:00:00
# 1               DET        Detroit Pistons  0022500842  2026-02-25T00:00:00
# 2               OKC  Oklahoma City Thunder  0022500842  2026-02-25T00:00:00
# 3               DEN         Denver Nuggets  0022500847  2026-02-25T00:00:00
# 4               DET        Detroit Pistons  0022500842  2026-02-25T00:00:00
#
#        MATCHUP  ... PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  \
# 0  HOU vs. SAC  ...     2029      1122              567                    43
# 1  DET vs. OKC  ...     2029       705             1418                   123
# 2    OKC @ DET  ...      671       594            17062                   646
# 3  DEN vs. BOS  ...      393       594             2346                   554
# 4  DET vs. OKC  ...     1189       705             2651                   518
#
#    DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK  AVAILABLE_FLAG  MIN_SEC  \
# 0         1         1                    119               1    32:03
# 1         1        92                    119               1    38:09
# 2         1        92                    343               1    35:27
# 3         1        92                    448               1    32:57
# 4         1        92                    772               1    31:16
#
#    TEAM_COUNT
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#
# [5 rows x 70 columns]

# %%
player_stats = df

# %%
df.columns
# Out:
# Index(['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
#        'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
#        'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2',
#        'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK',
#        'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK',
#        'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK',
#        'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK',
#        'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK',
#        'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK', 'TD3_RANK',
#        'WNBA_FANTASY_PTS_RANK', 'AVAILABLE_FLAG', 'MIN_SEC', 'TEAM_COUNT'],
#       dtype='object')

# %%
team_data = model_df

# %%
model_df.columns
# Out:
# Index(['GAME_ID', 'GAME_DATE', 'SEASON', 'HOME_TEAM', 'AWAY_TEAM', 'HOME_PTS',
#        'AWAY_PTS', 'TOTAL_PTS', 'HOME_ADV_OFF_RATING', 'HOME_ADV_DEF_RATING',
#        'HOME_ADV_NET_RATING', 'HOME_ADV_PACE', 'HOME_ADV_TS_PCT',
#        'HOME_ADV_EFG_PCT', 'HOME_ADV_OREB_PCT', 'HOME_ADV_DREB_PCT',
#        'HOME_ADV_TM_TOV_PCT', 'HOME_ADV_AST_RATIO', 'HOME_ADV_PIE',
#        'AWAY_ADV_OFF_RATING', 'AWAY_ADV_DEF_RATING', 'AWAY_ADV_NET_RATING',
#        'AWAY_ADV_PACE', 'AWAY_ADV_TS_PCT', 'AWAY_ADV_EFG_PCT',
#        'AWAY_ADV_OREB_PCT', 'AWAY_ADV_DREB_PCT', 'AWAY_ADV_TM_TOV_PCT',
#        'AWAY_ADV_AST_RATIO', 'AWAY_ADV_PIE', 'HOME_ADV_OFF_RATING_RANK',
#        'HOME_ADV_DEF_RATING_RANK', 'HOME_ADV_NET_RATING_RANK',
#        'HOME_ADV_PACE_RANK', 'AWAY_ADV_OFF_RATING_RANK',
#        'AWAY_ADV_DEF_RATING_RANK', 'AWAY_ADV_NET_RATING_RANK',
#        'AWAY_ADV_PACE_RANK', 'LINE', 'AVG_PACE', 'AVG_OFF_RTG', 'PACE_X_OFF',
#        'PACE_DIFF', 'OFF_VS_DEF', 'DEF_VS_OFF', 'HOME_STRENGTH',
#        'AWAY_STRENGTH', 'STRENGTH_DIFF', 'TS_PCT_DIFF', 'REB_BATTLE',
#        'TOV_BATTLE', 'HOME_OFF_ADV', 'HOME_DEF_ADV'],
#       dtype='object')

# %%
# Out:
# {'game_info': {'matchup': 'Cleveland Cavaliers @ Milwaukee Bucks',
#   'date': '2026-02-26',
#   'line': 222.5,
#   'data_source': 'Live NBA API (2025-26 season)'},
#  'team_stats': {'home': {'name': 'Milwaukee Bucks',
#    'off_rating': np.float64(113.6),
#    'def_rating': np.float64(116.5),
#    'net_rating': np.float64(-2.9),
#    'pace': np.float64(98.44)},
#   'away': {'name': 'Cleveland Cavaliers',
#    'off_rating': np.float64(117.6),
#    'def_rating': np.float64(113.1),
#    'net_rating': np.float64(4.4),
#    'pace': np.float64(101.3)}},
#  'predictions': {'home': {'team': 'Milwaukee Bucks',
#    'predicted': np.float64(116.0),
#    'confidence': np.float64(98.8),
#    'individual': {'xgb': np.float32(117.8),
#     'cat': np.float64(114.4),
#     'rf': np.float64(115.7)}},
#   'away': {'team': 'Cleveland Cavaliers',
#    'predicted': np.float64(118.7),
#    'confidence': np.float64(99.2),
#    'individual': {'xgb': np.float32(117.4),
#     'cat': np.float64(119.5),
#     'rf': np.float64(119.1)}},
#   'total': {'predicted': np.float64(239.3),
#    'line': 222.5,
#    'difference': np.float64(16.8),
#    'recommendation': 'OVER',
#    'confidence': np.float64(98.9),
#    'individual': {'xgb': np.float32(242.6),
#     'cat': np.float64(236.2),
#     'rf': np.float64(239.0)}}},
#  'implied_total': np.float64(234.6),
#  'verification': np.False_}

# %%
impact_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-535/444761301.py in <cell line: 0>()
# ----> 1 impact_df
#
# NameError: name 'impact_df' is not defined

# %%
results_team_pred = results

# %%
results_team_pred
# Out:
# [{'game_info': {'matchup': 'San Antonio Spurs @ Toronto Raptors',
#    'date': '2026-02-26',
#    'line': 230.5,
#    'data_source': 'Live NBA API (2025-26 season)'},
#   'team_stats': {'home': {'name': 'Toronto Raptors',
#     'off_rating': np.float64(113.5),
#     'def_rating': np.float64(111.7),
#     'net_rating': np.float64(1.8),
#     'pace': np.float64(99.38)},
#    'away': {'name': 'San Antonio Spurs',
#     'off_rating': np.float64(117.0),
#     'def_rating': np.float64(110.3),
#     'net_rating': np.float64(6.7),
#     'pace': np.float64(101.02)}},
#   'predictions': {'home': {'team': 'Toronto Raptors',
#     'predicted': np.float64(113.4),
#     'confidence': np.float64(98.7),
#     'individual': {'xgb': np.float32(114.7),
#      'cat': np.float64(111.3),
#      'rf': np.float64(114.2)}},
#    'away': {'team': 'San Antonio Spurs',
#     'predicted': np.float64(115.4),
#     'confidence': np.float64(99.0),
#     'individual': {'xgb': np.float32(116.2),
#      'cat': np.float64(113.7),
#      'rf': np.float64(116.2)}},
#    'total': {'predicted': np.float64(229.2),
#     'line': 230.5,
#     'difference': np.float64(-1.3),
#     'recommendation': 'UNDER',
#     'confidence': np.float64(98.0),
#     'individual': {'xgb': np.float32(232.5),
#      'cat': np.float64(222.6),
#      'rf': np.float64(232.4)}}},
#   'implied_total': np.float64(228.7),
#   'verification': np.False_},
#  {'game_info': {'matchup': 'Golden State Warriors @ Memphis Grizzlies',
#    'date': '2026-02-26',
#    'line': 224.5,
#    'data_source': 'Live NBA API (2025-26 season)'},
#   'team_stats': {'home': {'name': 'Memphis Grizzlies',
#     'off_rating': np.float64(113.1),
#     'def_rating': np.float64(115.9),
#     'net_rating': np.float64(-2.8),
#     'pace': np.float64(101.59)},
#    'away': {'name': 'Golden State Warriors',
#     'off_rating': np.float64(114.5),
#     'def_rating': np.float64(112.5),
#     'net_rating': np.float64(2.0),
#     'pace': np.float64(100.81)}},
#   'predictions': {'home': {'team': 'Memphis Grizzlies',
#     'predicted': np.float64(114.4),
#     'confidence': np.float64(98.7),
#     'individual': {'xgb': np.float32(115.9),
#      'cat': np.float64(112.4),
#      'rf': np.float64(115.0)}},
#    'away': {'team': 'Golden State Warriors',
#     'predicted': np.float64(114.1),
#     'confidence': np.float64(95.3),
#     'individual': {'xgb': np.float32(106.7),
#      'cat': np.float64(119.0),
#      'rf': np.float64(116.7)}},
#    'total': {'predicted': np.float64(227.9),
#     'line': 224.5,
#     'difference': np.float64(3.4),
#     'recommendation': 'OVER',
#     'confidence': np.float64(98.0),
#     'individual': {'xgb': np.float32(221.5),
#      'cat': np.float64(231.6),
#      'rf': np.float64(230.6)}}},
#   'implied_total': np.float64(228.6),
#   'verification': np.False_},
#  {'game_info': {'matchup': 'Oklahoma City Thunder @ Detroit Pistons',
#    'date': '2026-02-26',
#    'line': 219.5,
#    'data_source': 'Live NBA API (2025-26 season)'},
#   'team_stats': {'home': {'name': 'Detroit Pistons',
#     'off_rating': np.float64(116.6),
#     'def_rating': np.float64(108.5),
#     'net_rating': np.float64(8.1),
#     'pace': np.float64(100.49)},
#    'away': {'name': 'Oklahoma City Thunder',
#     'off_rating': np.float64(117.6),
#     'def_rating': np.float64(106.4),
#     'net_rating': np.float64(11.2),
#     'pace': np.float64(100.64)}},
#   'predictions': {'home': {'team': 'Detroit Pistons',
#     'predicted': np.float64(110.9),
#     'confidence': np.float64(97.6),
#     'individual': {'xgb': np.float32(112.5),
#      'cat': np.float64(107.2),
#      'rf': np.float64(113.1)}},
#    'away': {'team': 'Oklahoma City Thunder',
#     'predicted': np.float64(111.5),
#     'confidence': np.float64(99.4),
#     'individual': {'xgb': np.float32(110.8),
#      'cat': np.float64(111.3),
#      'rf': np.float64(112.4)}},
#    'total': {'predicted': np.float64(228.3),
#     'line': 219.5,
#     'difference': np.float64(8.8),
#     'recommendation': 'OVER',
#     'confidence': np.float64(99.3),
#     'individual': {'xgb': np.float32(228.9),
#      'cat': np.float64(226.2),
#      'rf': np.float64(229.7)}}},
#   'implied_total': np.float64(222.4),
#   'verification': np.False_},
#  {'game_info': {'matchup': 'Sacramento Kings @ Houston Rockets',
#    'date': '2026-02-26',
#    'line': 222.5,
#    'data_source': 'Live NBA API (2025-26 season)'},
#   'team_stats': {'home': {'name': 'Houston Rockets',
#     'off_rating': np.float64(117.1),
#     'def_rating': np.float64(111.4),
#     'net_rating': np.float64(5.6),
#     'pace': np.float64(96.74)},
#    'away': {'name': 'Sacramento Kings',
#     'off_rating': np.float64(109.4),
#     'def_rating': np.float64(120.1),
#     'net_rating': np.float64(-10.7),
#     'pace': np.float64(100.2)}},
#   'predictions': {'home': {'team': 'Houston Rockets',
#     'predicted': np.float64(119.2),
#     'confidence': np.float64(98.5),
#     'individual': {'xgb': np.float32(120.9),
#      'cat': np.float64(116.8),
#      'rf': np.float64(119.9)}},
#    'away': {'team': 'Sacramento Kings',
#     'predicted': np.float64(95.1),
#     'confidence': np.float64(98.9),
#     'individual': {'xgb': np.float32(96.5),
#      'cat': np.float64(94.1),
#      'rf': np.float64(94.7)}},
#    'total': {'predicted': np.float64(217.3),
#     'line': 222.5,
#     'difference': np.float64(-5.2),
#     'recommendation': 'UNDER',
#     'confidence': np.float64(99.8),
#     'individual': {'xgb': np.float32(217.7),
#      'cat': np.float64(217.4),
#      'rf': np.float64(216.8)}}},
#   'implied_total': np.float64(214.3),
#   'verification': np.False_},
#  {'game_info': {'matchup': 'Cleveland Cavaliers @ Milwaukee Bucks',
#    'date': '2026-02-26',
#    'line': 222.5,
#    'data_source': 'Live NBA API (2025-26 season)'},
#   'team_stats': {'home': {'name': 'Milwaukee Bucks',
#     'off_rating': np.float64(113.6),
#     'def_rating': np.float64(116.5),
#     'net_rating': np.float64(-2.9),
#     'pace': np.float64(98.44)},
#    'away': {'name': 'Cleveland Cavaliers',
#     'off_rating': np.float64(117.6),
#     'def_rating': np.float64(113.1),
#     'net_rating': np.float64(4.4),
#     'pace': np.float64(101.3)}},
#   'predictions': {'home': {'team': 'Milwaukee Bucks',
#     'predicted': np.float64(116.0),
#     'confidence': np.float64(98.8),
#     'individual': {'xgb': np.float32(117.8),
#      'cat': np.float64(114.4),
#      'rf': np.float64(115.7)}},
#    'away': {'team': 'Cleveland Cavaliers',
#     'predicted': np.float64(118.7),
#     'confidence': np.float64(99.2),
#     'individual': {'xgb': np.float32(117.4),
#      'cat': np.float64(119.5),
#      'rf': np.float64(119.1)}},
#    'total': {'predicted': np.float64(239.3),
#     'line': 222.5,
#     'difference': np.float64(16.8),
#     'recommendation': 'OVER',
#     'confidence': np.float64(98.9),
#     'individual': {'xgb': np.float32(242.6),
#      'cat': np.float64(236.2),
#      'rf': np.float64(239.0)}}},
#   'implied_total': np.float64(234.6),
#   'verification': np.False_}]

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# ============================================================================
# PLAYER PREDICTOR USING YOUR EXISTING DATA
# ============================================================================

class PlayerPredictor:
    """
    Predicts player statistics for games using:
    - results_team_pred: Team predictions
    - team_data: Team statistics (model_df)
    - player_stats: Player game logs
    """

    def __init__(self, player_stats_df, team_data_df):
        """
        Args:
            player_stats_df: Your player game logs dataframe (df)
            team_data_df: Your team statistics dataframe (model_df)
        """
        self.player_stats = player_stats_df.copy()
        self.team_data = team_data_df.copy()
        self._prepare_data()

    def _prepare_data(self):
        """Prepare the player data for analysis"""
        # Convert date to datetime
        self.player_stats['GAME_DATE'] = pd.to_datetime(self.player_stats['GAME_DATE'])

        # Create home/away indicator from MATCHUP
        self.player_stats['IS_HOME'] = self.player_stats['MATCHUP'].str.contains('vs.').astype(int)

        # Extract opponent from MATCHUP
        self.player_stats['OPPONENT'] = self.player_stats['MATCHUP'].apply(
            lambda x: x.split(' vs. ')[1] if 'vs.' in x else x.split(' @ ')[1]
        )

        # Sort by date for each player
        self.player_stats = self.player_stats.sort_values(['PLAYER_ID', 'GAME_DATE'])

        print(f"✅ Loaded {len(self.player_stats)} player game logs")
        print(f"✅ {self.player_stats['PLAYER_NAME'].nunique()} unique players")
        print(f"✅ Date range: {self.player_stats['GAME_DATE'].min().date()} to {self.player_stats['GAME_DATE'].max().date()}")

    def get_player_recent_form(self, player_id, current_date, num_games=5):
        """Get player's last N games averages"""
        player_games = self.player_stats[
            (self.player_stats['PLAYER_ID'] == player_id) &
            (self.player_stats['GAME_DATE'] < current_date)
        ].sort_values('GAME_DATE', ascending=False).head(num_games)

        if len(player_games) == 0:
            return None

        stats = {}

        # All possible stat columns from your dataframe
        stat_columns = ['MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT',
                       'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST',
                       'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS',
                       'PLUS_MINUS', 'NBA_FANTASY_PTS']

        for col in stat_columns:
            if col in player_games.columns:
                # Handle MIN column which might be in "MM:SS" format
                if col == 'MIN':
                    min_values = []
                    for min_str in player_games['MIN']:
                        if isinstance(min_str, str) and ':' in min_str:
                            parts = min_str.split(':')
                            min_values.append(float(parts[0]) + float(parts[1])/60)
                        else:
                            try:
                                min_values.append(float(min_str))
                            except:
                                min_values.append(0)
                    stats[f'LAST_{num_games}_AVG_MIN'] = np.mean(min_values)
                else:
                    stats[f'LAST_{num_games}_AVG_{col}'] = player_games[col].mean()
                    stats[f'LAST_{num_games}_MAX_{col}'] = player_games[col].max()

        # Games played
        stats[f'LAST_{num_games}_GAMES'] = len(player_games)

        return stats

    def get_player_vs_opponent(self, player_id, opponent_team, current_date):
        """Get player's performance against specific opponent"""
        player_vs_opp = self.player_stats[
            (self.player_stats['PLAYER_ID'] == player_id) &
            (self.player_stats['OPPONENT'] == opponent_team) &
            (self.player_stats['GAME_DATE'] < current_date)
        ].sort_values('GAME_DATE', ascending=False).head(3)  # Last 3 games vs opponent

        if len(player_vs_opp) == 0:
            return None

        stats = {}
        stat_columns = ['PTS', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'FG_PCT', 'MIN']

        for col in stat_columns:
            if col in player_vs_opp.columns:
                stats[f'VS_{opponent_team}_AVG_{col}'] = player_vs_opp[col].mean()

        stats[f'VS_{opponent_team}_GAMES'] = len(player_vs_opp)

        return stats

    def get_team_defensive_rating(self, team_name):
        """Get team's defensive rating from team_data"""
        # Look for the team in AWAY_TEAM or HOME_TEAM columns
        team_rows = self.team_data[
            (self.team_data['AWAY_TEAM'] == team_name) |
            (self.team_data['HOME_TEAM'] == team_name)
        ]

        if len(team_rows) > 0:
            # Get the most recent game's defensive ratings
            latest = team_rows.iloc[-1]

            if latest['AWAY_TEAM'] == team_name:
                return {
                    'def_rating': latest.get('AWAY_ADV_DEF_RATING', 110),
                    'off_rating': latest.get('AWAY_ADV_OFF_RATING', 110),
                    'pace': latest.get('AWAY_ADV_PACE', 100)
                }
            else:
                return {
                    'def_rating': latest.get('HOME_ADV_DEF_RATING', 110),
                    'off_rating': latest.get('HOME_ADV_OFF_RATING', 110),
                    'pace': latest.get('HOME_ADV_PACE', 100)
                }

        return {'def_rating': 110, 'off_rating': 110, 'pace': 100}

    def get_team_players(self, team_name, current_date):
        """Get all active players on a team"""
        # Get unique players who played for this team in the last 60 days
        recent_date = current_date - pd.Timedelta(days=60)

        team_players = self.player_stats[
            (self.player_stats['TEAM_NAME'] == team_name) &
            (self.player_stats['GAME_DATE'] >= recent_date)
        ].groupby('PLAYER_ID').agg({
            'PLAYER_NAME': 'first',
            'GAME_DATE': 'max'
        }).reset_index()

        return team_players

    def predict_game_players(self, team_prediction):
        """
        Predict all players for a game using team prediction

        Args:
            team_prediction: A single game prediction from results_team_pred
        """
        # Extract game info
        matchup = team_prediction['game_info']['matchup']
        away_team, home_team = matchup.split(' @ ')

        home_predicted_pts = team_prediction['predictions']['home']['predicted']
        away_predicted_pts = team_prediction['predictions']['away']['predicted']

        game_date = pd.to_datetime(team_prediction['game_info']['date'])

        print(f"\n{'='*70}")
        print(f"📊 PREDICTING PLAYERS: {away_team} @ {home_team}")
        print(f"{'='*70}")

        # Get team defensive ratings
        home_defense = self.get_team_defensive_rating(home_team)
        away_defense = self.get_team_defensive_rating(away_team)

        print(f"\n🏀 Team Context:")
        print(f"  {home_team} (Home) - Predicted: {home_predicted_pts:.1f} pts")
        print(f"    Def Rating: {home_defense['def_rating']:.1f} | Pace: {home_defense['pace']:.1f}")
        print(f"  {away_team} (Away) - Predicted: {away_predicted_pts:.1f} pts")
        print(f"    Def Rating: {away_defense['def_rating']:.1f} | Pace: {away_defense['pace']:.1f}")

        # Get players for both teams
        home_players = self.get_team_players(home_team, game_date)
        away_players = self.get_team_players(away_team, game_date)

        print(f"\n👥 Players with recent games:")
        print(f"  {home_team}: {len(home_players)} players")
        print(f"  {away_team}: {len(away_players)} players")

        all_predictions = []

        # Predict home players
        for _, row in home_players.iterrows():
            pred = self._predict_single_player(
                player_id=row['PLAYER_ID'],
                player_name=row['PLAYER_NAME'],
                team_name=home_team,
                opponent=away_team,
                is_home=True,
                game_date=game_date,
                team_predicted_pts=home_predicted_pts,
                opponent_def_rating=away_defense['def_rating']
            )
            if pred:
                all_predictions.append(pred)

        # Predict away players
        for _, row in away_players.iterrows():
            pred = self._predict_single_player(
                player_id=row['PLAYER_ID'],
                player_name=row['PLAYER_NAME'],
                team_name=away_team,
                opponent=home_team,
                is_home=False,
                game_date=game_date,
                team_predicted_pts=away_predicted_pts,
                opponent_def_rating=home_defense['def_rating']
            )
            if pred:
                all_predictions.append(pred)

        if not all_predictions:
            print("❌ No player predictions generated")
            return pd.DataFrame()

        # Create predictions dataframe
        predictions_df = pd.DataFrame(all_predictions)

        # Add matchup difficulty factor
        predictions_df = self._add_matchup_factors(predictions_df)

        # Sort by projected fantasy points
        if 'PROJECTED_FANTASY' in predictions_df.columns:
            predictions_df = predictions_df.sort_values('PROJECTED_FANTASY', ascending=False)

        return predictions_df

    def _predict_single_player(self, player_id, player_name, team_name, opponent,
                               is_home, game_date, team_predicted_pts, opponent_def_rating):
        """Predict single player performance"""

        # Get recent form
        recent = self.get_player_recent_form(player_id, game_date, num_games=5)

        if not recent:
            return None

        # Get vs opponent history
        vs_opp = self.get_player_vs_opponent(player_id, opponent, game_date)

        # Base prediction from recent form
        prediction = {
            'PLAYER_NAME': player_name,
            'TEAM': team_name,
            'OPPONENT': opponent,
            'IS_HOME': is_home,
            'GAME_DATE': game_date,
            'OPPONENT_DEF_RATING': opponent_def_rating
        }

        # Add recent stats
        for key, value in recent.items():
            prediction[key] = value

        # Add vs opponent stats if available
        if vs_opp:
            for key, value in vs_opp.items():
                prediction[key] = value
            prediction['HAS_VS_HISTORY'] = True
        else:
            prediction['HAS_VS_HISTORY'] = False

        # Calculate projected stats
        if 'LAST_5_AVG_PTS' in prediction:
            # Adjust for opponent defense
            # If opponent defense is better than average (lower rating), reduce points
            league_avg_def = 113.0  # Approximate league average
            def_factor = league_avg_def / opponent_def_rating if opponent_def_rating > 0 else 1.0
            def_factor = np.clip(def_factor, 0.85, 1.15)  # Limit adjustment

            # Home court advantage
            home_factor = 1.05 if is_home else 0.95

            # VS opponent boost if available
            opp_boost = 1.0
            if vs_opp and 'VS_' + opponent + '_AVG_PTS' in prediction:
                vs_pts = prediction['VS_' + opponent + '_AVG_PTS']
                recent_pts = prediction['LAST_5_AVG_PTS']
                if recent_pts > 0:
                    opp_boost = vs_pts / recent_pts
                    opp_boost = np.clip(opp_boost, 0.9, 1.1)

            # Combined adjustment
            prediction['DEF_ADJUSTMENT'] = def_factor
            prediction['HOME_ADJUSTMENT'] = home_factor
            prediction['MATCHUP_ADJUSTMENT'] = opp_boost

            # Projected points
            prediction['PROJECTED_PTS'] = prediction['LAST_5_AVG_PTS'] * def_factor * home_factor * opp_boost

            # Projected rebounds, assists, etc.
            for stat in ['REB', 'AST', 'STL', 'BLK', 'TOV']:
                if f'LAST_5_AVG_{stat}' in prediction:
                    prediction[f'PROJECTED_{stat}'] = prediction[f'LAST_5_AVG_{stat}'] * def_factor * home_factor

            # Calculate fantasy points (NBA Fantasy standard)
            fantasy_pts = (
                prediction.get('PROJECTED_PTS', 0) +
                prediction.get('PROJECTED_REB', 0) * 1.2 +
                prediction.get('PROJECTED_AST', 0) * 1.5 +
                prediction.get('PROJECTED_STL', 0) * 3 +
                prediction.get('PROJECTED_BLK', 0) * 3 -
                prediction.get('PROJECTED_TOV', 0)
            )
            prediction['PROJECTED_FANTASY'] = fantasy_pts

            # Team usage
            if team_predicted_pts > 0:
                prediction['USAGE_RATE'] = prediction['LAST_5_AVG_PTS'] / team_predicted_pts

        return prediction

    def _add_matchup_factors(self, df):
        """Add matchup difficulty tiers"""

        # Create difficulty rating based on opponent defense
        if 'OPPONENT_DEF_RATING' in df.columns:
            df['MATCHUP_DIFFICULTY'] = pd.cut(
                df['OPPONENT_DEF_RATING'],
                bins=[0, 108, 112, 116, 200],
                labels=['Elite Defense 🔒', 'Good Defense 🛡️',
                       'Average Defense ⚖️', 'Weak Defense 🎯']
            )

        # Create performance tiers based on fantasy projection
        if 'PROJECTED_FANTASY' in df.columns:
            df['PERFORMANCE_TIER'] = pd.cut(
                df['PROJECTED_FANTASY'],
                bins=[0, 15, 25, 35, 45, 200],
                labels=['Deep Bench', 'Role Player', 'Starter',
                       'Star', 'Superstar']
            )

        return df

    def print_player_predictions(self, predictions_df, team_name=None):
        """Pretty print player predictions"""
        if team_name:
            df = predictions_df[predictions_df['TEAM'] == team_name].copy()
            print(f"\n{'='*50}")
            print(f"{team_name} PLAYER PROJECTIONS")
            print(f"{'='*50}")
        else:
            df = predictions_df.copy()
            print(f"\n{'='*70}")
            print(f"ALL PLAYER PROJECTIONS")
            print(f"{'='*70}")

        if len(df) == 0:
            print("No players found")
            return

        for _, player in df.iterrows():
            # Player header
            home_away = "🏠" if player['IS_HOME'] else "🛣️"
            print(f"\n{home_away} {player['PLAYER_NAME']}")

            # Recent averages
            recent_stats = []
            for stat in ['PTS', 'REB', 'AST', 'STL', 'BLK']:
                col = f'LAST_5_AVG_{stat}'
                if col in player and not pd.isna(player[col]):
                    recent_stats.append(f"{stat}: {player[col]:.1f}")

            if recent_stats:
                print(f"  📊 Last 5: {', '.join(recent_stats)}")

            # Minutes
            if 'LAST_5_AVG_MIN' in player:
                print(f"  ⏱️ Minutes: {player['LAST_5_AVG_MIN']:.1f}")

            # Vs opponent if available
            if player.get('HAS_VS_HISTORY', False):
                opp_stats = []
                for stat in ['PTS', 'REB', 'AST']:
                    col = f'VS_{player["OPPONENT"]}_AVG_{stat}'
                    if col in player and not pd.isna(player[col]):
                        opp_stats.append(f"{stat}: {player[col]:.1f}")

                if opp_stats:
                    print(f"  🔥 vs {player['OPPONENT']}: {', '.join(opp_stats)}")

            # Projections
            projections = []
            if 'PROJECTED_PTS' in player:
                projections.append(f"PTS: {player['PROJECTED_PTS']:.1f}")
            if 'PROJECTED_REB' in player:
                projections.append(f"REB: {player['PROJECTED_REB']:.1f}")
            if 'PROJECTED_AST' in player:
                projections.append(f"AST: {player['PROJECTED_AST']:.1f}")

            if projections:
                print(f"  🎯 Projected: {', '.join(projections)}")

            # Fantasy points and tier
            if 'PROJECTED_FANTASY' in player:
                fantasy = player['PROJECTED_FANTASY']
                tier = player.get('PERFORMANCE_TIER', 'N/A')

                # Color code based on fantasy points
                if fantasy > 40:
                    emoji = "👑"
                elif fantasy > 30:
                    emoji = "⭐"
                elif fantasy > 20:
                    emoji = "📈"
                else:
                    emoji = "📊"

                print(f"  {emoji} Fantasy: {fantasy:.1f} ({tier})")

            # Matchup difficulty
            if 'MATCHUP_DIFFICULTY' in player:
                print(f"  🎯 Matchup: {player['MATCHUP_DIFFICULTY']}")

    def predict_all_todays_games(self, team_predictions):
        """
        Predict players for all games in team_predictions

        Args:
            team_predictions: Your results_team_pred list
        """
        all_game_predictions = []

        for i, game_pred in enumerate(team_predictions, 1):
            print(f"\n{'#'*80}")
            print(f"GAME {i} of {len(team_predictions)}")
            print(f"{'#'*80}")

            player_preds = self.predict_game_players(game_pred)

            if len(player_preds) > 0:
                all_game_predictions.append({
                    'game_info': game_pred['game_info'],
                    'team_predictions': game_pred['predictions'],
                    'player_predictions': player_preds.to_dict('records'),
                    'top_performers': self.get_top_performers(player_preds),
                    'sleepers': self.get_sleepers(player_preds)
                })

                # Print summary for this game
                self.print_game_summary(game_pred, player_preds)

        return all_game_predictions

    def get_top_performers(self, predictions_df, n=5):
        """Get top projected performers"""
        if 'PROJECTED_FANTASY' in predictions_df.columns:
            return predictions_df.nlargest(n, 'PROJECTED_FANTASY')[
                ['PLAYER_NAME', 'TEAM', 'PROJECTED_FANTASY', 'PERFORMANCE_TIER']
            ].to_dict('records')
        return []

    def get_sleepers(self, predictions_df, minutes_threshold=22, fantasy_threshold=20):
        """Get sleeper picks (low minutes but good production)"""
        if 'LAST_5_AVG_MIN' in predictions_df.columns and 'PROJECTED_FANTASY' in predictions_df.columns:
            sleepers = predictions_df[
                (predictions_df['LAST_5_AVG_MIN'] < minutes_threshold) &
                (predictions_df['PROJECTED_FANTASY'] > fantasy_threshold)
            ].nlargest(3, 'PROJECTED_FANTASY')

            if len(sleepers) > 0:
                return sleepers[['PLAYER_NAME', 'TEAM', 'LAST_5_AVG_MIN',
                                'PROJECTED_FANTASY']].to_dict('records')
        return []

    def print_game_summary(self, team_pred, player_preds):
        """Print summary for a game"""
        matchup = team_pred['game_info']['matchup']
        home_team = matchup.split(' @ ')[1]
        away_team = matchup.split(' @ ')[0]

        print(f"\n{'='*60}")
        print(f"📋 GAME SUMMARY: {matchup}")
        print(f"{'='*60}")

        # Team predictions
        home_pts = team_pred['predictions']['home']['predicted']
        away_pts = team_pred['predictions']['away']['predicted']
        total = team_pred['predictions']['total']['predicted']
        line = team_pred['game_info']['line']

        print(f"\n🏀 Team Projections:")
        print(f"  {home_team}: {home_pts:.1f} pts (Home)")
        print(f"  {away_team}: {away_pts:.1f} pts (Away)")
        print(f"  Total: {total:.1f} | Line: {line} | {team_pred['predictions']['total']['recommendation']}")

        # Top performers
        top = self.get_top_performers(player_preds, 3)
        if top:
            print(f"\n🌟 Top 3 Projected:")
            for i, p in enumerate(top, 1):
                print(f"  {i}. {p['PLAYER_NAME']} ({p['TEAM']}) - {p['PROJECTED_FANTASY']:.1f} fantasy pts")

        # Sleepers
        sleepers = self.get_sleepers(player_preds)
        if sleepers:
            print(f"\n💤 Sleeper Picks:")
            for s in sleepers:
                print(f"  • {s['PLAYER_NAME']} ({s['TEAM']}) - {s['LAST_5_AVG_MIN']:.0f} min, {s['PROJECTED_FANTASY']:.1f} fantasy")


# ============================================================================
# RUN PREDICTIONS WITH YOUR DATA
# ============================================================================

# Initialize predictor with your data
print("🎯 INITIALIZING PLAYER PREDICTOR...")
print("="*70)

predictor = PlayerPredictor(
    player_stats_df=player_stats,  # Your df variable
    team_data_df=team_data          # Your model_df variable
)

# Predict all games from results_team_pred
print("\n📊 PREDICTING ALL TODAY'S GAMES...")
all_predictions = predictor.predict_all_todays_games(results_team_pred)

# Print detailed player predictions for each game
for i, game in enumerate(all_predictions):
    print(f"\n{'#'*80}")
    print(f"DETAILED PLAYER PREDICTIONS - GAME {i+1}")
    print(f"{'#'*80}")

    matchup = game['game_info']['matchup']
    home_team = matchup.split(' @ ')[1]
    away_team = matchup.split(' @ ')[0]

    # Convert player predictions back to DataFrame
    player_df = pd.DataFrame(game['player_predictions'])

    # Print home team players
    predictor.print_player_predictions(player_df, home_team)

    # Print away team players
    predictor.print_player_predictions(player_df, away_team)

    print("\n" + "="*70)


# ============================================================================
# EXPORT PREDICTIONS TO CSV
# ============================================================================

def export_predictions_to_csv(all_predictions, filename="player_predictions.csv"):
    """Export all player predictions to CSV"""
    all_players = []

    for game in all_predictions:
        for player in game['player_predictions']:
            player_copy = player.copy()
            player_copy['game_matchup'] = game['game_info']['matchup']
            player_copy['game_date'] = game['game_info']['date']
            all_players.append(player_copy)

    if all_players:
        df_export = pd.DataFrame(all_players)
        df_export.to_csv(filename, index=False)
        print(f"\n✅ Predictions exported to {filename}")
        return df_export

    return None

# Export to CSV
# export_predictions_to_csv(all_predictions, "todays_player_predictions.csv")
# Out:
# 🎯 INITIALIZING PLAYER PREDICTOR...
# ======================================================================
# ✅ Loaded 18982 player game logs
# ✅ 540 unique players
# ✅ Date range: 2025-10-21 to 2026-02-25
#
# 📊 PREDICTING ALL TODAY'S GAMES...
#
# ################################################################################
# GAME 1 of 5
# ################################################################################
#
# ======================================================================
# 📊 PREDICTING PLAYERS: San Antonio Spurs @ Toronto Raptors
# ======================================================================
#
# 🏀 Team Context:
#   Toronto Raptors (Home) - Predicted: 113.4 pts
#     Def Rating: 111.7 | Pace: 99.4
#   San Antonio Spurs (Away) - Predicted: 115.4 pts
#     Def Rating: 110.3 | Pace: 101.0
#
# 👥 Players with recent games:
#   Toronto Raptors: 18 players
#   San Antonio Spurs: 18 players
#
# ============================================================
# 📋 GAME SUMMARY: San Antonio Spurs @ Toronto Raptors
# ============================================================
#
# 🏀 Team Projections:
#   Toronto Raptors: 113.4 pts (Home)
#   San Antonio Spurs: 115.4 pts (Away)
#   Total: 229.2 | Line: 230.5 | UNDER
#
# 🌟 Top 3 Projected:
#   1. Victor Wembanyama (San Antonio Spurs) - 53.7 fantasy pts
#   2. Scottie Barnes (Toronto Raptors) - 49.7 fantasy pts
#   3. Brandon Ingram (Toronto Raptors) - 36.4 fantasy pts
#
# 💤 Sleeper Picks:
#   • Jamal Shead (Toronto Raptors) - 22 min, 21.0 fantasy
#
# ################################################################################
# GAME 2 of 5
# ################################################################################
#
# ======================================================================
# 📊 PREDICTING PLAYERS: Golden State Warriors @ Memphis Grizzlies
# ======================================================================
#
# 🏀 Team Context:
#   Memphis Grizzlies (Home) - Predicted: 114.4 pts
#     Def Rating: 115.9 | Pace: 101.6
#   Golden State Warriors (Away) - Predicted: 114.1 pts
#     Def Rating: 112.5 | Pace: 100.8
#
# 👥 Players with recent games:
#   Memphis Grizzlies: 22 players
#   Golden State Warriors: 18 players
#
# ============================================================
# 📋 GAME SUMMARY: Golden State Warriors @ Memphis Grizzlies
# ============================================================
#
# 🏀 Team Projections:
#   Memphis Grizzlies: 114.4 pts (Home)
#   Golden State Warriors: 114.1 pts (Away)
#   Total: 227.9 | Line: 224.5 | OVER
#
# 🌟 Top 3 Projected:
#   1. Ja Morant (Memphis Grizzlies) - 45.9 fantasy pts
#   2. Jaren Jackson Jr. (Memphis Grizzlies) - 42.7 fantasy pts
#   3. GG Jackson (Memphis Grizzlies) - 37.5 fantasy pts
#
# 💤 Sleeper Picks:
#   • Ty Jerome (Memphis Grizzlies) - 21 min, 33.9 fantasy
#   • Scotty Pippen Jr. (Memphis Grizzlies) - 20 min, 27.7 fantasy
#   • Jonathan Kuminga (Golden State Warriors) - 17 min, 22.6 fantasy
#
# ################################################################################
# GAME 3 of 5
# ################################################################################
#
# ======================================================================
# 📊 PREDICTING PLAYERS: Oklahoma City Thunder @ Detroit Pistons
# ======================================================================
#
# 🏀 Team Context:
#   Detroit Pistons (Home) - Predicted: 110.9 pts
#     Def Rating: 108.5 | Pace: 100.5
#   Oklahoma City Thunder (Away) - Predicted: 111.5 pts
#     Def Rating: 106.4 | Pace: 100.6
#
# 👥 Players with recent games:
#   Detroit Pistons: 18 players
#   Oklahoma City Thunder: 19 players
#
# ============================================================
# 📋 GAME SUMMARY: Oklahoma City Thunder @ Detroit Pistons
# ============================================================
#
# 🏀 Team Projections:
#   Detroit Pistons: 110.9 pts (Home)
#   Oklahoma City Thunder: 111.5 pts (Away)
#   Total: 228.3 | Line: 219.5 | OVER
#
# 🌟 Top 3 Projected:
#   1. Cade Cunningham (Detroit Pistons) - 68.4 fantasy pts
#   2. Shai Gilgeous-Alexander (Oklahoma City Thunder) - 46.9 fantasy pts
#   3. Jalen Duren (Detroit Pistons) - 39.8 fantasy pts
#
# 💤 Sleeper Picks:
#   • Ronald Holland II (Detroit Pistons) - 19 min, 23.6 fantasy
#   • Jaylin Williams (Oklahoma City Thunder) - 20 min, 22.3 fantasy
#   • Ousmane Dieng (Oklahoma City Thunder) - 22 min, 21.1 fantasy
#
# ################################################################################
# GAME 4 of 5
# ################################################################################
#
# ======================================================================
# 📊 PREDICTING PLAYERS: Sacramento Kings @ Houston Rockets
# ======================================================================
#
# 🏀 Team Context:
#   Houston Rockets (Home) - Predicted: 119.2 pts
#     Def Rating: 111.4 | Pace: 96.7
#   Sacramento Kings (Away) - Predicted: 95.1 pts
#     Def Rating: 120.1 | Pace: 100.2
#
# 👥 Players with recent games:
#   Houston Rockets: 15 players
#   Sacramento Kings: 20 players
#
# ============================================================
# 📋 GAME SUMMARY: Sacramento Kings @ Houston Rockets
# ============================================================
#
# 🏀 Team Projections:
#   Houston Rockets: 119.2 pts (Home)
#   Sacramento Kings: 95.1 pts (Away)
#   Total: 217.3 | Line: 222.5 | UNDER
#
# 🌟 Top 3 Projected:
#   1. Alperen Sengun (Houston Rockets) - 45.7 fantasy pts
#   2. Kevin Durant (Houston Rockets) - 41.3 fantasy pts
#   3. Domantas Sabonis (Sacramento Kings) - 37.8 fantasy pts
#
# 💤 Sleeper Picks:
#   • Malik Monk (Sacramento Kings) - 22 min, 20.6 fantasy
#
# ################################################################################
# GAME 5 of 5
# ################################################################################
#
# ======================================================================
# 📊 PREDICTING PLAYERS: Cleveland Cavaliers @ Milwaukee Bucks
# ======================================================================
#
# 🏀 Team Context:
#   Milwaukee Bucks (Home) - Predicted: 116.0 pts
#     Def Rating: 116.5 | Pace: 98.4
#   Cleveland Cavaliers (Away) - Predicted: 118.7 pts
#     Def Rating: 113.1 | Pace: 101.3
#
# 👥 Players with recent games:
#   Milwaukee Bucks: 17 players
#   Cleveland Cavaliers: 19 players
#
# ============================================================
# 📋 GAME SUMMARY: Cleveland Cavaliers @ Milwaukee Bucks
# ============================================================
#
# 🏀 Team Projections:
#   Milwaukee Bucks: 116.0 pts (Home)
#   Cleveland Cavaliers: 118.7 pts (Away)
#   Total: 239.3 | Line: 222.5 | OVER
#
# 🌟 Top 3 Projected:
#   1. Kevin Porter Jr. (Milwaukee Bucks) - 49.4 fantasy pts
#   2. Giannis Antetokounmpo (Milwaukee Bucks) - 44.8 fantasy pts
#   3. Ryan Rollins (Milwaukee Bucks) - 38.6 fantasy pts
#
# 💤 Sleeper Picks:
#   • Ousmane Dieng (Milwaukee Bucks) - 22 min, 22.4 fantasy
#
# ################################################################################
# DETAILED PLAYER PREDICTIONS - GAME 1
# ################################################################################
#
# ==================================================
# Toronto Raptors PLAYER PROJECTIONS
# ==================================================
#
# 🏠 Scottie Barnes
#   📊 Last 5: PTS: 17.2, REB: 7.4, AST: 5.0, STL: 2.6, BLK: 2.6
#   ⏱️ Minutes: 32.0
#   🎯 Projected: PTS: 18.5, REB: 8.0, AST: 5.4
#   👑 Fantasy: 49.7 (Superstar)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Brandon Ingram
#   📊 Last 5: PTS: 20.2, REB: 5.4, AST: 4.4, STL: 0.4, BLK: 0.6
#   ⏱️ Minutes: 34.3
#   🎯 Projected: PTS: 21.7, REB: 5.8, AST: 4.7
#   ⭐ Fantasy: 36.4 (Star)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Immanuel Quickley
#   📊 Last 5: PTS: 20.2, REB: 2.8, AST: 4.2, STL: 0.8, BLK: 0.0
#   ⏱️ Minutes: 33.0
#   🎯 Projected: PTS: 21.7, REB: 3.0, AST: 4.5
#   ⭐ Fantasy: 33.4 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 RJ Barrett
#   📊 Last 5: PTS: 13.8, REB: 6.0, AST: 3.4, STL: 1.0, BLK: 0.4
#   ⏱️ Minutes: 29.7
#   🎯 Projected: PTS: 14.8, REB: 6.5, AST: 3.7
#   ⭐ Fantasy: 31.1 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Ja'Kobe Walter
#   📊 Last 5: PTS: 9.6, REB: 4.8, AST: 1.8, STL: 1.2, BLK: 0.2
#   ⏱️ Minutes: 22.7
#   🎯 Projected: PTS: 10.3, REB: 5.2, AST: 1.9
#   📈 Fantasy: 22.9 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Jamal Shead
#   📊 Last 5: PTS: 8.2, REB: 2.6, AST: 4.0, STL: 1.2, BLK: 0.0
#   ⏱️ Minutes: 21.7
#   🎯 Projected: PTS: 8.8, REB: 2.8, AST: 4.3
#   📈 Fantasy: 21.0 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Jakob Poeltl
#   📊 Last 5: PTS: 6.8, REB: 4.6, AST: 1.0, STL: 0.6, BLK: 0.6
#   ⏱️ Minutes: 19.4
#   🎯 Projected: PTS: 7.3, REB: 4.9, AST: 1.1
#   📊 Fantasy: 17.9 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Collin Murray-Boyles
#   📊 Last 5: PTS: 5.8, REB: 3.8, AST: 0.8, STL: 1.0, BLK: 0.8
#   ⏱️ Minutes: 20.4
#   🎯 Projected: PTS: 6.2, REB: 4.1, AST: 0.9
#   📊 Fantasy: 17.8 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Sandro Mamukelashvili
#   📊 Last 5: PTS: 6.8, REB: 3.6, AST: 1.2, STL: 0.4, BLK: 0.2
#   ⏱️ Minutes: 17.6
#   🎯 Projected: PTS: 7.3, REB: 3.9, AST: 1.3
#   📊 Fantasy: 15.6 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Ochai Agbaji
#   📊 Last 5: PTS: 6.4, REB: 2.8, AST: 1.6, STL: 0.2, BLK: 0.6
#   ⏱️ Minutes: 17.2
#   🎯 Projected: PTS: 6.9, REB: 3.0, AST: 1.7
#   📊 Fantasy: 15.0 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Gradey Dick
#   📊 Last 5: PTS: 4.4, REB: 2.4, AST: 0.4, STL: 1.2, BLK: 0.2
#   ⏱️ Minutes: 12.6
#   🎯 Projected: PTS: 4.7, REB: 2.6, AST: 0.4
#   📊 Fantasy: 11.7 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Trayce Jackson-Davis
#   📊 Last 5: PTS: 2.4, REB: 3.0, AST: 0.4, STL: 0.4, BLK: 0.4
#   ⏱️ Minutes: 6.2
#   🎯 Projected: PTS: 2.6, REB: 3.2, AST: 0.4
#   📊 Fantasy: 9.3 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Jonathan Mogbo
#   📊 Last 5: PTS: 0.6, REB: 2.0, AST: 0.0, STL: 0.4, BLK: 0.2
#   ⏱️ Minutes: 5.9
#   🎯 Projected: PTS: 0.6, REB: 2.2, AST: 0.0
#   📊 Fantasy: 4.3 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Jamison Battle
#   📊 Last 5: PTS: 1.8, REB: 1.2, AST: 0.2, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 7.1
#   🎯 Projected: PTS: 1.9, REB: 1.3, AST: 0.2
#   📊 Fantasy: 3.6 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 A.J. Lawson
#   📊 Last 5: PTS: 2.2, REB: 0.8, AST: 0.0, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 4.6
#   🎯 Projected: PTS: 2.4, REB: 0.9, AST: 0.0
#   📊 Fantasy: 3.2 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Mo Bamba
#   📊 Last 5: PTS: 0.0, REB: 1.0, AST: 0.0, STL: 0.0, BLK: 0.5
#   ⏱️ Minutes: 2.9
#   🎯 Projected: PTS: 0.0, REB: 1.1, AST: 0.0
#   📊 Fantasy: 2.9 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Alijah Martin
#   📊 Last 5: PTS: 1.2, REB: 0.4, AST: 0.2, STL: 0.2, BLK: 0.0
#   ⏱️ Minutes: 2.6
#   🎯 Projected: PTS: 1.3, REB: 0.4, AST: 0.2
#   📊 Fantasy: 2.8 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🏠 Garrett Temple
#   📊 Last 5: PTS: 0.0, REB: 0.0, AST: 0.2, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 2.2
#   🎯 Projected: PTS: 0.0, REB: 0.0, AST: 0.2
#   📊 Fantasy: 0.3 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# ==================================================
# San Antonio Spurs PLAYER PROJECTIONS
# ==================================================
#
# 🛣️ Victor Wembanyama
#   📊 Last 5: PTS: 20.8, REB: 12.0, AST: 4.2, STL: 1.0, BLK: 4.4
#   ⏱️ Minutes: 30.6
#   🎯 Projected: PTS: 20.0, REB: 11.5, AST: 4.0
#   👑 Fantasy: 53.7 (Superstar)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ De'Aaron Fox
#   📊 Last 5: PTS: 18.0, REB: 2.8, AST: 5.8, STL: 1.4, BLK: 0.0
#   ⏱️ Minutes: 29.1
#   🎯 Projected: PTS: 17.3, REB: 2.7, AST: 5.6
#   ⭐ Fantasy: 30.4 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Stephon Castle
#   📊 Last 5: PTS: 15.0, REB: 4.2, AST: 5.4, STL: 1.0, BLK: 0.4
#   ⏱️ Minutes: 25.0
#   🎯 Projected: PTS: 14.4, REB: 4.0, AST: 5.2
#   📈 Fantasy: 28.4 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Dylan Harper
#   📊 Last 5: PTS: 12.6, REB: 3.6, AST: 4.8, STL: 0.8, BLK: 0.0
#   ⏱️ Minutes: 25.1
#   🎯 Projected: PTS: 12.1, REB: 3.5, AST: 4.6
#   📈 Fantasy: 24.3 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Devin Vassell
#   📊 Last 5: PTS: 15.4, REB: 3.2, AST: 2.6, STL: 0.4, BLK: 0.4
#   ⏱️ Minutes: 28.6
#   🎯 Projected: PTS: 14.8, REB: 3.1, AST: 2.5
#   📈 Fantasy: 23.0 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Julian Champagnie
#   📊 Last 5: PTS: 8.6, REB: 5.0, AST: 2.2, STL: 0.6, BLK: 0.6
#   ⏱️ Minutes: 26.9
#   🎯 Projected: PTS: 8.3, REB: 4.8, AST: 2.1
#   📈 Fantasy: 20.5 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Luke Kornet
#   📊 Last 5: PTS: 5.2, REB: 5.4, AST: 1.4, STL: 0.6, BLK: 0.6
#   ⏱️ Minutes: 14.9
#   🎯 Projected: PTS: 5.0, REB: 5.2, AST: 1.3
#   📊 Fantasy: 16.7 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Harrison Barnes
#   📊 Last 5: PTS: 8.6, REB: 3.2, AST: 2.2, STL: 0.6, BLK: 0.0
#   ⏱️ Minutes: 19.8
#   🎯 Projected: PTS: 8.3, REB: 3.1, AST: 2.1
#   📊 Fantasy: 16.7 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Keldon Johnson
#   📊 Last 5: PTS: 11.2, REB: 2.8, AST: 1.2, STL: 0.4, BLK: 0.0
#   ⏱️ Minutes: 21.2
#   🎯 Projected: PTS: 10.8, REB: 2.7, AST: 1.2
#   📊 Fantasy: 16.3 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Carter Bryant
#   📊 Last 5: PTS: 4.6, REB: 3.0, AST: 0.6, STL: 0.0, BLK: 0.4
#   ⏱️ Minutes: 9.3
#   🎯 Projected: PTS: 4.4, REB: 2.9, AST: 0.6
#   📊 Fantasy: 9.1 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Kelly Olynyk
#   📊 Last 5: PTS: 2.8, REB: 1.8, AST: 0.6, STL: 0.2, BLK: 0.0
#   ⏱️ Minutes: 8.1
#   🎯 Projected: PTS: 2.7, REB: 1.7, AST: 0.6
#   📊 Fantasy: 4.9 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Jordan McLaughlin
#   📊 Last 5: PTS: 2.0, REB: 0.6, AST: 0.4, STL: 0.4, BLK: 0.2
#   ⏱️ Minutes: 7.3
#   🎯 Projected: PTS: 1.9, REB: 0.6, AST: 0.4
#   📊 Fantasy: 4.7 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Jeremy Sochan
#   📊 Last 5: PTS: 0.8, REB: 1.0, AST: 0.6, STL: 0.2, BLK: 0.4
#   ⏱️ Minutes: 6.8
#   🎯 Projected: PTS: 0.8, REB: 1.0, AST: 0.6
#   📊 Fantasy: 4.5 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ David Jones Garcia
#   📊 Last 5: PTS: 1.8, REB: 0.4, AST: 1.0, STL: 0.4, BLK: 0.0
#   ⏱️ Minutes: 3.8
#   🎯 Projected: PTS: 1.7, REB: 0.4, AST: 1.0
#   📊 Fantasy: 4.4 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Stanley Umude
#   📊 Last 5: PTS: 1.0, REB: 0.0, AST: 0.5, STL: 0.5, BLK: 0.0
#   ⏱️ Minutes: 3.3
#   🎯 Projected: PTS: 1.0, REB: 0.0, AST: 0.5
#   📊 Fantasy: 3.1 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Harrison Ingram
#   📊 Last 5: PTS: 1.8, REB: 0.6, AST: 0.2, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 3.5
#   🎯 Projected: PTS: 1.7, REB: 0.6, AST: 0.2
#   📊 Fantasy: 2.7 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Bismack Biyombo
#   📊 Last 5: PTS: 0.4, REB: 1.2, AST: 0.2, STL: 0.2, BLK: 0.0
#   ⏱️ Minutes: 4.9
#   🎯 Projected: PTS: 0.4, REB: 1.2, AST: 0.2
#   📊 Fantasy: 2.2 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Lindy Waters III
#   📊 Last 5: PTS: 1.0, REB: 0.2, AST: 0.2, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 5.7
#   🎯 Projected: PTS: 1.0, REB: 0.2, AST: 0.2
#   📊 Fantasy: 0.9 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# ======================================================================
#
# ################################################################################
# DETAILED PLAYER PREDICTIONS - GAME 2
# ################################################################################
#
# ==================================================
# Memphis Grizzlies PLAYER PROJECTIONS
# ==================================================
#
# 🏠 Ja Morant
#   📊 Last 5: PTS: 24.8, REB: 2.4, AST: 9.2, STL: 1.2, BLK: 0.6
#   ⏱️ Minutes: 30.3
#   🎯 Projected: PTS: 26.2, REB: 2.5, AST: 9.7
#   👑 Fantasy: 45.9 (Superstar)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Jaren Jackson Jr.
#   📊 Last 5: PTS: 22.6, REB: 5.6, AST: 2.4, STL: 2.4, BLK: 0.8
#   ⏱️ Minutes: 27.4
#   🎯 Projected: PTS: 23.8, REB: 5.9, AST: 2.5
#   👑 Fantasy: 42.7 (Star)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 GG Jackson
#   📊 Last 5: PTS: 21.8, REB: 6.4, AST: 2.2, STL: 0.6, BLK: 1.2
#   ⏱️ Minutes: 26.6
#   🎯 Projected: PTS: 23.0, REB: 6.7, AST: 2.3
#   ⭐ Fantasy: 37.5 (Star)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Ty Jerome
#   📊 Last 5: PTS: 18.0, REB: 2.8, AST: 4.8, STL: 1.4, BLK: 0.4
#   ⏱️ Minutes: 21.4
#   🎯 Projected: PTS: 19.0, REB: 3.0, AST: 5.1
#   ⭐ Fantasy: 33.9 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Javon Small
#   📊 Last 5: PTS: 14.2, REB: 4.0, AST: 4.0, STL: 1.6, BLK: 0.4
#   ⏱️ Minutes: 25.7
#   🎯 Projected: PTS: 15.0, REB: 4.2, AST: 4.2
#   ⭐ Fantasy: 31.9 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Santi Aldama
#   📊 Last 5: PTS: 14.2, REB: 6.2, AST: 1.8, STL: 0.6, BLK: 1.0
#   ⏱️ Minutes: 28.0
#   🎯 Projected: PTS: 15.0, REB: 6.5, AST: 1.9
#   📈 Fantasy: 29.9 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Scotty Pippen Jr.
#   📊 Last 5: PTS: 10.2, REB: 1.6, AST: 5.0, STL: 2.6, BLK: 0.6
#   ⏱️ Minutes: 20.2
#   🎯 Projected: PTS: 10.8, REB: 1.7, AST: 5.3
#   📈 Fantasy: 27.7 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Olivier-Maxence Prosper
#   📊 Last 5: PTS: 13.2, REB: 3.6, AST: 1.6, STL: 1.4, BLK: 0.6
#   ⏱️ Minutes: 24.8
#   🎯 Projected: PTS: 13.9, REB: 3.8, AST: 1.7
#   📈 Fantasy: 26.5 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Jaylen Wells
#   📊 Last 5: PTS: 15.0, REB: 2.2, AST: 2.0, STL: 1.2, BLK: 0.4
#   ⏱️ Minutes: 26.1
#   🎯 Projected: PTS: 15.8, REB: 2.3, AST: 2.1
#   📈 Fantasy: 25.4 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Lawson Lovering
#   📊 Last 5: PTS: 7.0, REB: 7.5, AST: 1.5, STL: 1.5, BLK: 0.5
#   ⏱️ Minutes: 24.6
#   🎯 Projected: PTS: 7.4, REB: 7.9, AST: 1.6
#   📈 Fantasy: 24.5 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Cedric Coward
#   📊 Last 5: PTS: 8.0, REB: 5.6, AST: 2.8, STL: 0.8, BLK: 0.6
#   ⏱️ Minutes: 23.7
#   🎯 Projected: PTS: 8.4, REB: 5.9, AST: 3.0
#   📈 Fantasy: 22.5 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Taylor Hendricks
#   📊 Last 5: PTS: 9.8, REB: 4.4, AST: 1.6, STL: 1.2, BLK: 0.6
#   ⏱️ Minutes: 24.4
#   🎯 Projected: PTS: 10.3, REB: 4.6, AST: 1.7
#   📈 Fantasy: 22.4 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Walter Clayton Jr.
#   📊 Last 5: PTS: 8.2, REB: 2.4, AST: 5.2, STL: 1.0, BLK: 0.0
#   ⏱️ Minutes: 23.6
#   🎯 Projected: PTS: 8.6, REB: 2.5, AST: 5.5
#   📈 Fantasy: 21.0 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Jock Landale
#   📊 Last 5: PTS: 9.0, REB: 5.0, AST: 1.0, STL: 0.6, BLK: 0.4
#   ⏱️ Minutes: 19.3
#   🎯 Projected: PTS: 9.5, REB: 5.3, AST: 1.1
#   📈 Fantasy: 20.4 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 John Konchar
#   📊 Last 5: PTS: 3.4, REB: 3.6, AST: 2.2, STL: 2.2, BLK: 0.6
#   ⏱️ Minutes: 23.0
#   🎯 Projected: PTS: 3.6, REB: 3.8, AST: 2.3
#   📊 Fantasy: 19.8 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Kyle Anderson
#   📊 Last 5: PTS: 7.8, REB: 3.0, AST: 1.4, STL: 1.4, BLK: 0.8
#   ⏱️ Minutes: 21.8
#   🎯 Projected: PTS: 8.2, REB: 3.2, AST: 1.5
#   📊 Fantasy: 19.7 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Jahmai Mashack
#   📊 Last 5: PTS: 8.2, REB: 2.8, AST: 1.4, STL: 1.4, BLK: 0.8
#   ⏱️ Minutes: 23.9
#   🎯 Projected: PTS: 8.6, REB: 3.0, AST: 1.5
#   📊 Fantasy: 19.7 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Cam Spencer
#   📊 Last 5: PTS: 4.8, REB: 2.2, AST: 5.8, STL: 0.6, BLK: 0.2
#   ⏱️ Minutes: 21.3
#   🎯 Projected: PTS: 5.1, REB: 2.3, AST: 6.1
#   📊 Fantasy: 19.1 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Kentavious Caldwell-Pope
#   📊 Last 5: PTS: 10.0, REB: 2.6, AST: 1.8, STL: 1.0, BLK: 0.0
#   ⏱️ Minutes: 24.0
#   🎯 Projected: PTS: 10.5, REB: 2.7, AST: 1.9
#   📊 Fantasy: 18.4 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Vince Williams Jr.
#   📊 Last 5: PTS: 5.6, REB: 3.8, AST: 3.0, STL: 0.4, BLK: 0.2
#   ⏱️ Minutes: 14.8
#   🎯 Projected: PTS: 5.9, REB: 4.0, AST: 3.2
#   📊 Fantasy: 15.9 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Christian Koloko
#   📊 Last 5: PTS: 4.0, REB: 3.8, AST: 0.8, STL: 0.2, BLK: 0.8
#   ⏱️ Minutes: 16.5
#   🎯 Projected: PTS: 4.2, REB: 4.0, AST: 0.8
#   📊 Fantasy: 13.0 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Rayan Rupert
#   📊 Last 5: PTS: 5.0, REB: 3.6, AST: 0.4, STL: 1.0, BLK: 0.0
#   ⏱️ Minutes: 16.4
#   🎯 Projected: PTS: 5.3, REB: 3.8, AST: 0.4
#   📊 Fantasy: 12.6 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# ==================================================
# Golden State Warriors PLAYER PROJECTIONS
# ==================================================
#
# 🛣️ Jimmy Butler III
#   📊 Last 5: PTS: 22.0, REB: 6.0, AST: 5.0, STL: 1.2, BLK: 0.0
#   ⏱️ Minutes: 27.1
#   🎯 Projected: PTS: 20.4, REB: 5.6, AST: 4.6
#   ⭐ Fantasy: 36.2 (Star)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Brandin Podziemski
#   📊 Last 5: PTS: 16.0, REB: 10.0, AST: 5.2, STL: 1.0, BLK: 0.2
#   ⏱️ Minutes: 32.5
#   🎯 Projected: PTS: 14.8, REB: 9.3, AST: 4.8
#   ⭐ Fantasy: 34.6 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Gui Santos
#   📊 Last 5: PTS: 15.0, REB: 6.2, AST: 4.6, STL: 2.0, BLK: 0.8
#   ⏱️ Minutes: 30.9
#   🎯 Projected: PTS: 13.9, REB: 5.7, AST: 4.3
#   ⭐ Fantasy: 32.9 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Stephen Curry
#   📊 Last 5: PTS: 26.0, REB: 2.2, AST: 3.0, STL: 1.4, BLK: 0.2
#   ⏱️ Minutes: 28.0
#   🎯 Projected: PTS: 24.1, REB: 2.0, AST: 2.8
#   ⭐ Fantasy: 32.5 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ De'Anthony Melton
#   📊 Last 5: PTS: 18.6, REB: 3.4, AST: 3.0, STL: 1.2, BLK: 0.0
#   ⏱️ Minutes: 25.8
#   🎯 Projected: PTS: 17.2, REB: 3.1, AST: 2.8
#   📈 Fantasy: 26.8 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Al Horford
#   📊 Last 5: PTS: 11.8, REB: 5.8, AST: 4.2, STL: 0.8, BLK: 0.8
#   ⏱️ Minutes: 26.8
#   🎯 Projected: PTS: 10.9, REB: 5.4, AST: 3.9
#   📈 Fantasy: 26.7 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Moses Moody
#   📊 Last 5: PTS: 17.8, REB: 4.2, AST: 3.0, STL: 0.4, BLK: 0.0
#   ⏱️ Minutes: 30.9
#   🎯 Projected: PTS: 16.5, REB: 3.9, AST: 2.8
#   📈 Fantasy: 25.5 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Draymond Green
#   📊 Last 5: PTS: 10.2, REB: 5.8, AST: 5.0, STL: 0.6, BLK: 0.4
#   ⏱️ Minutes: 27.4
#   🎯 Projected: PTS: 9.4, REB: 5.4, AST: 4.6
#   📈 Fantasy: 23.2 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Jonathan Kuminga
#   📊 Last 5: PTS: 12.6, REB: 4.8, AST: 2.4, STL: 1.0, BLK: 0.2
#   ⏱️ Minutes: 17.2
#   🎯 Projected: PTS: 11.7, REB: 4.4, AST: 2.2
#   📈 Fantasy: 22.6 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Gary Payton II
#   📊 Last 5: PTS: 12.4, REB: 2.8, AST: 2.6, STL: 1.4, BLK: 0.2
#   ⏱️ Minutes: 18.4
#   🎯 Projected: PTS: 11.5, REB: 2.6, AST: 2.4
#   📈 Fantasy: 21.2 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Will Richard
#   📊 Last 5: PTS: 10.4, REB: 3.6, AST: 2.2, STL: 1.4, BLK: 0.2
#   ⏱️ Minutes: 23.2
#   🎯 Projected: PTS: 9.6, REB: 3.3, AST: 2.0
#   📈 Fantasy: 20.6 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Pat Spencer
#   📊 Last 5: PTS: 6.6, REB: 2.0, AST: 5.8, STL: 1.0, BLK: 0.2
#   ⏱️ Minutes: 26.3
#   🎯 Projected: PTS: 6.1, REB: 1.9, AST: 5.4
#   📊 Fantasy: 18.1 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Kristaps Porziņģis
#   📊 Last 5: PTS: 10.8, REB: 3.0, AST: 1.4, STL: 0.6, BLK: 0.4
#   ⏱️ Minutes: 18.7
#   🎯 Projected: PTS: 10.0, REB: 2.8, AST: 1.3
#   📊 Fantasy: 16.9 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Quinten Post
#   📊 Last 5: PTS: 6.0, REB: 5.4, AST: 1.8, STL: 0.2, BLK: 0.6
#   ⏱️ Minutes: 16.6
#   🎯 Projected: PTS: 5.6, REB: 5.0, AST: 1.7
#   📊 Fantasy: 15.2 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Buddy Hield
#   📊 Last 5: PTS: 7.4, REB: 2.4, AST: 2.4, STL: 0.8, BLK: 0.2
#   ⏱️ Minutes: 19.1
#   🎯 Projected: PTS: 6.9, REB: 2.2, AST: 2.2
#   📊 Fantasy: 14.5 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Malevy Leons
#   📊 Last 5: PTS: 3.0, REB: 3.0, AST: 0.6, STL: 0.6, BLK: 0.4
#   ⏱️ Minutes: 7.2
#   🎯 Projected: PTS: 2.8, REB: 2.8, AST: 0.6
#   📊 Fantasy: 9.4 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ Trayce Jackson-Davis
#   📊 Last 5: PTS: 2.4, REB: 3.0, AST: 0.4, STL: 0.4, BLK: 0.4
#   ⏱️ Minutes: 6.2
#   🎯 Projected: PTS: 2.2, REB: 2.8, AST: 0.4
#   📊 Fantasy: 8.0 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# 🛣️ LJ Cryer
#   📊 Last 5: PTS: 2.0, REB: 0.3, AST: 0.0, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 2.6
#   🎯 Projected: PTS: 1.9, REB: 0.3, AST: 0.0
#   📊 Fantasy: 2.2 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# ======================================================================
#
# ################################################################################
# DETAILED PLAYER PREDICTIONS - GAME 3
# ################################################################################
#
# ==================================================
# Detroit Pistons PLAYER PROJECTIONS
# ==================================================
#
# 🏠 Cade Cunningham
#   📊 Last 5: PTS: 26.6, REB: 6.8, AST: 11.6, STL: 2.0, BLK: 2.4
#   ⏱️ Minutes: 34.4
#   🎯 Projected: PTS: 29.7, REB: 7.6, AST: 12.9
#   👑 Fantasy: 68.4 (Superstar)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Jalen Duren
#   📊 Last 5: PTS: 19.8, REB: 10.0, AST: 1.4, STL: 0.8, BLK: 0.2
#   ⏱️ Minutes: 24.4
#   🎯 Projected: PTS: 22.1, REB: 11.2, AST: 1.6
#   ⭐ Fantasy: 39.8 (Star)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Paul Reed
#   📊 Last 5: PTS: 14.6, REB: 6.4, AST: 1.0, STL: 1.2, BLK: 2.8
#   ⏱️ Minutes: 23.5
#   🎯 Projected: PTS: 16.3, REB: 7.1, AST: 1.1
#   ⭐ Fantasy: 38.8 (Star)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Tobias Harris
#   📊 Last 5: PTS: 9.8, REB: 8.8, AST: 1.8, STL: 1.0, BLK: 0.6
#   ⏱️ Minutes: 29.3
#   🎯 Projected: PTS: 10.9, REB: 9.8, AST: 2.0
#   📈 Fantasy: 30.0 (Starter)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Jaden Ivey
#   📊 Last 5: PTS: 10.8, REB: 4.2, AST: 3.4, STL: 1.8, BLK: 0.4
#   ⏱️ Minutes: 27.2
#   🎯 Projected: PTS: 12.0, REB: 4.7, AST: 3.8
#   📈 Fantasy: 29.4 (Starter)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Ausar Thompson
#   📊 Last 5: PTS: 8.2, REB: 4.0, AST: 5.0, STL: 2.0, BLK: 0.6
#   ⏱️ Minutes: 26.7
#   🎯 Projected: PTS: 9.1, REB: 4.5, AST: 5.6
#   📈 Fantasy: 29.3 (Starter)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Duncan Robinson
#   📊 Last 5: PTS: 13.6, REB: 2.8, AST: 2.2, STL: 0.4, BLK: 0.2
#   ⏱️ Minutes: 25.2
#   🎯 Projected: PTS: 15.2, REB: 3.1, AST: 2.5
#   📈 Fantasy: 23.9 (Role Player)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Ronald Holland II
#   📊 Last 5: PTS: 8.8, REB: 5.6, AST: 1.6, STL: 1.2, BLK: 0.2
#   ⏱️ Minutes: 18.6
#   🎯 Projected: PTS: 9.8, REB: 6.2, AST: 1.8
#   📈 Fantasy: 23.6 (Role Player)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Caris LeVert
#   📊 Last 5: PTS: 7.6, REB: 1.0, AST: 1.6, STL: 0.6, BLK: 1.0
#   ⏱️ Minutes: 18.7
#   🎯 Projected: PTS: 8.5, REB: 1.1, AST: 1.8
#   📊 Fantasy: 15.6 (Role Player)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Isaiah Stewart
#   📊 Last 5: PTS: 8.2, REB: 2.4, AST: 0.8, STL: 0.4, BLK: 0.4
#   ⏱️ Minutes: 21.1
#   🎯 Projected: PTS: 9.1, REB: 2.7, AST: 0.9
#   📊 Fantasy: 15.3 (Role Player)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Tolu Smith
#   📊 Last 5: PTS: 3.2, REB: 4.4, AST: 0.8, STL: 0.2, BLK: 0.8
#   ⏱️ Minutes: 13.2
#   🎯 Projected: PTS: 3.6, REB: 4.9, AST: 0.9
#   📊 Fantasy: 13.2 (Deep Bench)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Javonte Green
#   📊 Last 5: PTS: 4.0, REB: 3.2, AST: 0.6, STL: 0.6, BLK: 0.4
#   ⏱️ Minutes: 16.7
#   🎯 Projected: PTS: 4.5, REB: 3.6, AST: 0.7
#   📊 Fantasy: 12.4 (Deep Bench)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Marcus Sasser
#   📊 Last 5: PTS: 4.6, REB: 0.4, AST: 2.2, STL: 0.8, BLK: 0.0
#   ⏱️ Minutes: 8.9
#   🎯 Projected: PTS: 5.1, REB: 0.4, AST: 2.5
#   📊 Fantasy: 10.9 (Deep Bench)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Daniss Jenkins
#   📊 Last 5: PTS: 6.0, REB: 2.2, AST: 1.0, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 18.2
#   🎯 Projected: PTS: 6.7, REB: 2.5, AST: 1.1
#   📊 Fantasy: 10.0 (Deep Bench)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Kevin Huerter
#   📊 Last 5: PTS: 3.4, REB: 1.4, AST: 0.6, STL: 0.6, BLK: 0.2
#   ⏱️ Minutes: 11.1
#   🎯 Projected: PTS: 3.8, REB: 1.6, AST: 0.7
#   📊 Fantasy: 8.9 (Deep Bench)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Wendell Moore Jr.
#   📊 Last 5: PTS: 2.0, REB: 1.2, AST: 0.6, STL: 0.4, BLK: 0.4
#   ⏱️ Minutes: 10.9
#   🎯 Projected: PTS: 2.2, REB: 1.3, AST: 0.7
#   📊 Fantasy: 7.3 (Deep Bench)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Chaz Lanier
#   📊 Last 5: PTS: 3.4, REB: 1.0, AST: 0.4, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 5.8
#   🎯 Projected: PTS: 3.8, REB: 1.1, AST: 0.4
#   📊 Fantasy: 5.6 (Deep Bench)
#   🎯 Matchup: Elite Defense 🔒
#
# 🏠 Bobi Klintman
#   📊 Last 5: PTS: 1.6, REB: 1.4, AST: 0.2, STL: 0.2, BLK: 0.0
#   ⏱️ Minutes: 5.9
#   🎯 Projected: PTS: 1.8, REB: 1.6, AST: 0.2
#   📊 Fantasy: 4.2 (Deep Bench)
#   🎯 Matchup: Elite Defense 🔒
#
# ==================================================
# Oklahoma City Thunder PLAYER PROJECTIONS
# ==================================================
#
# 🛣️ Shai Gilgeous-Alexander
#   📊 Last 5: PTS: 27.4, REB: 5.0, AST: 8.0, STL: 1.2, BLK: 0.6
#   ⏱️ Minutes: 32.7
#   🎯 Projected: PTS: 27.1, REB: 4.9, AST: 7.9
#   👑 Fantasy: 46.9 (Superstar)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Cason Wallace
#   📊 Last 5: PTS: 16.2, REB: 4.0, AST: 6.2, STL: 1.8, BLK: 0.4
#   ⏱️ Minutes: 31.4
#   🎯 Projected: PTS: 16.0, REB: 4.0, AST: 6.1
#   ⭐ Fantasy: 34.9 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Chet Holmgren
#   📊 Last 5: PTS: 13.6, REB: 9.6, AST: 3.2, STL: 0.4, BLK: 1.6
#   ⏱️ Minutes: 27.7
#   🎯 Projected: PTS: 13.5, REB: 9.5, AST: 3.2
#   ⭐ Fantasy: 34.0 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Isaiah Hartenstein
#   📊 Last 5: PTS: 10.4, REB: 7.4, AST: 4.0, STL: 1.0, BLK: 0.8
#   ⏱️ Minutes: 23.0
#   🎯 Projected: PTS: 10.3, REB: 7.3, AST: 4.0
#   📈 Fantasy: 29.0 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Jalen Williams
#   📊 Last 5: PTS: 17.0, REB: 3.0, AST: 4.4, STL: 0.6, BLK: 0.2
#   ⏱️ Minutes: 23.9
#   🎯 Projected: PTS: 16.8, REB: 3.0, AST: 4.4
#   📈 Fantasy: 27.9 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Isaiah Joe
#   📊 Last 5: PTS: 15.0, REB: 3.4, AST: 2.0, STL: 2.0, BLK: 0.0
#   ⏱️ Minutes: 25.5
#   🎯 Projected: PTS: 14.8, REB: 3.4, AST: 2.0
#   📈 Fantasy: 26.8 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Ajay Mitchell
#   📊 Last 5: PTS: 13.2, REB: 4.0, AST: 4.0, STL: 1.2, BLK: 0.2
#   ⏱️ Minutes: 26.3
#   🎯 Projected: PTS: 13.1, REB: 4.0, AST: 4.0
#   📈 Fantasy: 25.1 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Jaylin Williams
#   📊 Last 5: PTS: 11.2, REB: 5.6, AST: 2.4, STL: 0.2, BLK: 0.6
#   ⏱️ Minutes: 20.5
#   🎯 Projected: PTS: 11.1, REB: 5.5, AST: 2.4
#   📈 Fantasy: 22.3 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Ousmane Dieng
#   📊 Last 5: PTS: 9.0, REB: 4.8, AST: 2.0, STL: 0.6, BLK: 1.0
#   ⏱️ Minutes: 21.8
#   🎯 Projected: PTS: 8.9, REB: 4.7, AST: 2.0
#   📈 Fantasy: 21.1 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Luguentz Dort
#   📊 Last 5: PTS: 9.8, REB: 3.0, AST: 2.4, STL: 1.2, BLK: 0.2
#   ⏱️ Minutes: 31.1
#   🎯 Projected: PTS: 9.7, REB: 3.0, AST: 2.4
#   📊 Fantasy: 20.0 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Jared McCain
#   📊 Last 5: PTS: 13.8, REB: 3.4, AST: 1.0, STL: 0.6, BLK: 0.0
#   ⏱️ Minutes: 20.5
#   🎯 Projected: PTS: 13.7, REB: 3.4, AST: 1.0
#   📊 Fantasy: 20.0 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Aaron Wiggins
#   📊 Last 5: PTS: 9.4, REB: 3.2, AST: 2.6, STL: 0.6, BLK: 0.2
#   ⏱️ Minutes: 24.3
#   🎯 Projected: PTS: 9.3, REB: 3.2, AST: 2.6
#   📊 Fantasy: 16.8 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Alex Caruso
#   📊 Last 5: PTS: 8.4, REB: 1.4, AST: 2.0, STL: 1.0, BLK: 0.0
#   ⏱️ Minutes: 17.0
#   🎯 Projected: PTS: 8.3, REB: 1.4, AST: 2.0
#   📊 Fantasy: 14.5 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Kenrich Williams
#   📊 Last 5: PTS: 7.4, REB: 3.4, AST: 0.6, STL: 0.4, BLK: 0.2
#   ⏱️ Minutes: 18.4
#   🎯 Projected: PTS: 7.3, REB: 3.4, AST: 0.6
#   📊 Fantasy: 13.0 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Branden Carlson
#   📊 Last 5: PTS: 4.0, REB: 3.4, AST: 0.6, STL: 0.0, BLK: 0.6
#   ⏱️ Minutes: 9.9
#   🎯 Projected: PTS: 4.0, REB: 3.4, AST: 0.6
#   📊 Fantasy: 10.3 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Brooks Barnhizer
#   📊 Last 5: PTS: 2.8, REB: 2.4, AST: 1.4, STL: 0.2, BLK: 0.4
#   ⏱️ Minutes: 10.8
#   🎯 Projected: PTS: 2.8, REB: 2.4, AST: 1.4
#   📊 Fantasy: 8.9 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Chris Youngblood
#   📊 Last 5: PTS: 3.6, REB: 1.0, AST: 0.8, STL: 0.2, BLK: 0.4
#   ⏱️ Minutes: 6.9
#   🎯 Projected: PTS: 3.6, REB: 1.0, AST: 0.8
#   📊 Fantasy: 7.5 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Nikola Topić
#   📊 Last 5: PTS: 3.2, REB: 1.6, AST: 2.0, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 10.5
#   🎯 Projected: PTS: 3.2, REB: 1.6, AST: 2.0
#   📊 Fantasy: 5.9 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Buddy Boeheim
#   📊 Last 5: PTS: 1.5, REB: 0.0, AST: 0.0, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 3.8
#   🎯 Projected: PTS: 1.5, REB: 0.0, AST: 0.0
#   📊 Fantasy: 1.5 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# ======================================================================
#
# ################################################################################
# DETAILED PLAYER PREDICTIONS - GAME 4
# ################################################################################
#
# ==================================================
# Houston Rockets PLAYER PROJECTIONS
# ==================================================
#
# 🏠 Alperen Sengun
#   📊 Last 5: PTS: 17.4, REB: 7.8, AST: 7.8, STL: 1.2, BLK: 2.4
#   ⏱️ Minutes: 32.0
#   🎯 Projected: PTS: 17.2, REB: 7.7, AST: 7.7
#   👑 Fantasy: 45.7 (Superstar)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Kevin Durant
#   📊 Last 5: PTS: 25.0, REB: 6.2, AST: 6.0, STL: 0.4, BLK: 1.0
#   ⏱️ Minutes: 34.5
#   🎯 Projected: PTS: 24.7, REB: 6.1, AST: 5.9
#   👑 Fantasy: 41.3 (Star)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Jabari Smith Jr.
#   📊 Last 5: PTS: 19.0, REB: 6.8, AST: 1.0, STL: 1.0, BLK: 1.2
#   ⏱️ Minutes: 33.6
#   🎯 Projected: PTS: 18.8, REB: 6.7, AST: 1.0
#   ⭐ Fantasy: 33.5 (Starter)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Amen Thompson
#   📊 Last 5: PTS: 13.8, REB: 7.2, AST: 3.6, STL: 2.2, BLK: 0.8
#   ⏱️ Minutes: 37.1
#   🎯 Projected: PTS: 13.6, REB: 7.1, AST: 3.6
#   ⭐ Fantasy: 33.4 (Starter)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Reed Sheppard
#   📊 Last 5: PTS: 16.6, REB: 3.0, AST: 3.2, STL: 0.8, BLK: 0.8
#   ⏱️ Minutes: 25.2
#   🎯 Projected: PTS: 16.4, REB: 3.0, AST: 3.2
#   📈 Fantasy: 27.5 (Starter)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Tari Eason
#   📊 Last 5: PTS: 9.6, REB: 5.8, AST: 2.4, STL: 1.0, BLK: 0.4
#   ⏱️ Minutes: 30.9
#   🎯 Projected: PTS: 9.5, REB: 5.7, AST: 2.4
#   📈 Fantasy: 22.7 (Role Player)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Steven Adams
#   📊 Last 5: PTS: 4.6, REB: 8.6, AST: 1.4, STL: 0.4, BLK: 0.8
#   ⏱️ Minutes: 25.4
#   🎯 Projected: PTS: 4.5, REB: 8.5, AST: 1.4
#   📊 Fantasy: 19.6 (Role Player)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Aaron Holiday
#   📊 Last 5: PTS: 6.2, REB: 1.2, AST: 1.2, STL: 0.6, BLK: 0.0
#   ⏱️ Minutes: 12.5
#   🎯 Projected: PTS: 6.1, REB: 1.2, AST: 1.2
#   📊 Fantasy: 10.7 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Clint Capela
#   📊 Last 5: PTS: 2.2, REB: 3.4, AST: 0.2, STL: 0.2, BLK: 1.2
#   ⏱️ Minutes: 11.9
#   🎯 Projected: PTS: 2.2, REB: 3.4, AST: 0.2
#   📊 Fantasy: 10.3 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Josh Okogie
#   📊 Last 5: PTS: 4.4, REB: 2.2, AST: 0.2, STL: 1.0, BLK: 0.0
#   ⏱️ Minutes: 15.8
#   🎯 Projected: PTS: 4.3, REB: 2.2, AST: 0.2
#   📊 Fantasy: 9.6 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Dorian Finney-Smith
#   📊 Last 5: PTS: 3.8, REB: 2.4, AST: 0.8, STL: 0.2, BLK: 0.2
#   ⏱️ Minutes: 20.2
#   🎯 Projected: PTS: 3.8, REB: 2.4, AST: 0.8
#   📊 Fantasy: 7.8 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 JD Davison
#   📊 Last 5: PTS: 3.2, REB: 1.6, AST: 1.6, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 8.0
#   🎯 Projected: PTS: 3.2, REB: 1.6, AST: 1.6
#   📊 Fantasy: 7.0 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Isaiah Crawford
#   📊 Last 5: PTS: 2.0, REB: 1.2, AST: 0.6, STL: 0.4, BLK: 0.6
#   ⏱️ Minutes: 8.5
#   🎯 Projected: PTS: 2.0, REB: 1.2, AST: 0.6
#   📊 Fantasy: 6.9 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Jae'Sean Tate
#   📊 Last 5: PTS: 3.8, REB: 0.8, AST: 0.4, STL: 0.6, BLK: 0.0
#   ⏱️ Minutes: 10.8
#   🎯 Projected: PTS: 3.8, REB: 0.8, AST: 0.4
#   📊 Fantasy: 6.7 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🏠 Jeff Green
#   📊 Last 5: PTS: 2.8, REB: 0.6, AST: 0.4, STL: 0.2, BLK: 0.0
#   ⏱️ Minutes: 6.4
#   🎯 Projected: PTS: 2.8, REB: 0.6, AST: 0.4
#   📊 Fantasy: 4.7 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# ==================================================
# Sacramento Kings PLAYER PROJECTIONS
# ==================================================
#
# 🛣️ Domantas Sabonis
#   📊 Last 5: PTS: 17.0, REB: 11.4, AST: 5.4, STL: 0.8, BLK: 0.2
#   ⏱️ Minutes: 28.1
#   🎯 Projected: PTS: 16.4, REB: 11.0, AST: 5.2
#   ⭐ Fantasy: 37.8 (Star)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ DeMar DeRozan
#   📊 Last 5: PTS: 17.4, REB: 2.0, AST: 4.6, STL: 1.0, BLK: 0.6
#   ⏱️ Minutes: 27.2
#   🎯 Projected: PTS: 16.8, REB: 1.9, AST: 4.4
#   📈 Fantasy: 29.8 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Dylan Cardwell
#   📊 Last 5: PTS: 8.6, REB: 11.4, AST: 2.0, STL: 1.0, BLK: 1.2
#   ⏱️ Minutes: 28.2
#   🎯 Projected: PTS: 8.3, REB: 11.0, AST: 1.9
#   📈 Fantasy: 29.8 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Maxime Raynaud
#   📊 Last 5: PTS: 12.2, REB: 10.2, AST: 2.4, STL: 0.4, BLK: 0.4
#   ⏱️ Minutes: 29.9
#   🎯 Projected: PTS: 11.8, REB: 9.8, AST: 2.3
#   📈 Fantasy: 28.8 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Precious Achiuwa
#   📊 Last 5: PTS: 12.4, REB: 8.0, AST: 1.4, STL: 1.4, BLK: 0.8
#   ⏱️ Minutes: 26.7
#   🎯 Projected: PTS: 11.9, REB: 7.7, AST: 1.3
#   📈 Fantasy: 28.0 (Starter)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Zach LaVine
#   📊 Last 5: PTS: 17.2, REB: 2.8, AST: 2.0, STL: 1.0, BLK: 0.2
#   ⏱️ Minutes: 25.6
#   🎯 Projected: PTS: 16.6, REB: 2.7, AST: 1.9
#   📈 Fantasy: 24.8 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Nique Clifford
#   📊 Last 5: PTS: 9.2, REB: 4.6, AST: 3.4, STL: 2.8, BLK: 0.0
#   ⏱️ Minutes: 31.1
#   🎯 Projected: PTS: 8.9, REB: 4.4, AST: 3.3
#   📈 Fantasy: 24.5 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Dennis Schröder
#   📊 Last 5: PTS: 12.0, REB: 2.0, AST: 4.6, STL: 1.6, BLK: 0.2
#   ⏱️ Minutes: 23.7
#   🎯 Projected: PTS: 11.6, REB: 1.9, AST: 4.4
#   📈 Fantasy: 24.0 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Devin Carter
#   📊 Last 5: PTS: 12.0, REB: 3.6, AST: 3.4, STL: 1.0, BLK: 0.4
#   ⏱️ Minutes: 24.2
#   🎯 Projected: PTS: 11.6, REB: 3.5, AST: 3.3
#   📈 Fantasy: 22.8 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Keegan Murray
#   📊 Last 5: PTS: 11.2, REB: 3.8, AST: 1.8, STL: 0.2, BLK: 1.6
#   ⏱️ Minutes: 27.4
#   🎯 Projected: PTS: 10.8, REB: 3.7, AST: 1.7
#   📈 Fantasy: 21.6 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Russell Westbrook
#   📊 Last 5: PTS: 15.2, REB: 2.4, AST: 3.0, STL: 0.6, BLK: 0.2
#   ⏱️ Minutes: 23.4
#   🎯 Projected: PTS: 14.6, REB: 2.3, AST: 2.9
#   📈 Fantasy: 21.0 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Malik Monk
#   📊 Last 5: PTS: 13.6, REB: 1.6, AST: 3.0, STL: 0.8, BLK: 0.2
#   ⏱️ Minutes: 21.7
#   🎯 Projected: PTS: 13.1, REB: 1.5, AST: 2.9
#   📈 Fantasy: 20.6 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Keon Ellis
#   📊 Last 5: PTS: 7.6, REB: 2.4, AST: 2.0, STL: 1.4, BLK: 1.2
#   ⏱️ Minutes: 22.3
#   🎯 Projected: PTS: 7.3, REB: 2.3, AST: 1.9
#   📊 Fantasy: 19.7 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Daeqwon Plowden
#   📊 Last 5: PTS: 8.2, REB: 3.2, AST: 1.2, STL: 0.8, BLK: 0.4
#   ⏱️ Minutes: 22.2
#   🎯 Projected: PTS: 7.9, REB: 3.1, AST: 1.2
#   📊 Fantasy: 16.2 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ De'Andre Hunter
#   📊 Last 5: PTS: 12.0, REB: 1.8, AST: 0.6, STL: 0.8, BLK: 0.0
#   ⏱️ Minutes: 22.8
#   🎯 Projected: PTS: 11.6, REB: 1.7, AST: 0.6
#   📊 Fantasy: 15.5 (Role Player)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Isaiah Stevens
#   📊 Last 5: PTS: 3.3, REB: 1.0, AST: 3.3, STL: 1.7, BLK: 0.0
#   ⏱️ Minutes: 14.3
#   🎯 Projected: PTS: 3.2, REB: 1.0, AST: 3.2
#   📊 Fantasy: 13.4 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Drew Eubanks
#   📊 Last 5: PTS: 2.6, REB: 3.2, AST: 1.4, STL: 0.2, BLK: 0.4
#   ⏱️ Minutes: 9.0
#   🎯 Projected: PTS: 2.5, REB: 3.1, AST: 1.3
#   📊 Fantasy: 10.0 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Doug McDermott
#   📊 Last 5: PTS: 5.6, REB: 0.8, AST: 0.4, STL: 0.6, BLK: 0.0
#   ⏱️ Minutes: 9.2
#   🎯 Projected: PTS: 5.4, REB: 0.8, AST: 0.4
#   📊 Fantasy: 8.1 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Killian Hayes
#   📊 Last 5: PTS: 1.5, REB: 0.5, AST: 3.5, STL: 0.5, BLK: 0.0
#   ⏱️ Minutes: 15.5
#   🎯 Projected: PTS: 1.4, REB: 0.5, AST: 3.4
#   📊 Fantasy: 8.0 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# 🛣️ Patrick Baldwin Jr.
#   📊 Last 5: PTS: 3.8, REB: 1.2, AST: 0.2, STL: 0.2, BLK: 0.0
#   ⏱️ Minutes: 8.9
#   🎯 Projected: PTS: 3.6, REB: 1.2, AST: 0.2
#   📊 Fantasy: 5.7 (Deep Bench)
#   🎯 Matchup: Good Defense 🛡️
#
# ======================================================================
#
# ################################################################################
# DETAILED PLAYER PREDICTIONS - GAME 5
# ################################################################################
#
# ==================================================
# Milwaukee Bucks PLAYER PROJECTIONS
# ==================================================
#
# 🏠 Kevin Porter Jr.
#   📊 Last 5: PTS: 22.0, REB: 4.4, AST: 7.2, STL: 3.0, BLK: 0.6
#   ⏱️ Minutes: 33.9
#   🎯 Projected: PTS: 23.1, REB: 4.6, AST: 7.6
#   👑 Fantasy: 49.4 (Superstar)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Giannis Antetokounmpo
#   📊 Last 5: PTS: 21.6, REB: 11.4, AST: 5.2, STL: 1.0, BLK: 0.2
#   ⏱️ Minutes: 29.2
#   🎯 Projected: PTS: 22.7, REB: 12.0, AST: 5.5
#   👑 Fantasy: 44.8 (Star)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Ryan Rollins
#   📊 Last 5: PTS: 20.2, REB: 4.8, AST: 4.8, STL: 1.8, BLK: 0.8
#   ⏱️ Minutes: 34.4
#   🎯 Projected: PTS: 21.2, REB: 5.0, AST: 5.0
#   ⭐ Fantasy: 38.6 (Star)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Bobby Portis
#   📊 Last 5: PTS: 13.8, REB: 7.4, AST: 1.4, STL: 0.8, BLK: 0.2
#   ⏱️ Minutes: 23.9
#   🎯 Projected: PTS: 14.5, REB: 7.8, AST: 1.5
#   📈 Fantasy: 28.7 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Myles Turner
#   📊 Last 5: PTS: 9.8, REB: 5.2, AST: 1.2, STL: 1.0, BLK: 2.2
#   ⏱️ Minutes: 25.1
#   🎯 Projected: PTS: 10.3, REB: 5.5, AST: 1.3
#   📈 Fantasy: 27.9 (Starter)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Kyle Kuzma
#   📊 Last 5: PTS: 13.4, REB: 3.8, AST: 2.4, STL: 0.6, BLK: 0.0
#   ⏱️ Minutes: 24.6
#   🎯 Projected: PTS: 14.1, REB: 4.0, AST: 2.5
#   📈 Fantasy: 23.7 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Ousmane Dieng
#   📊 Last 5: PTS: 9.0, REB: 4.8, AST: 2.0, STL: 0.6, BLK: 1.0
#   ⏱️ Minutes: 21.8
#   🎯 Projected: PTS: 9.4, REB: 5.0, AST: 2.1
#   📈 Fantasy: 22.4 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Jericho Sims
#   📊 Last 5: PTS: 7.0, REB: 7.8, AST: 2.0, STL: 0.0, BLK: 0.8
#   ⏱️ Minutes: 24.2
#   🎯 Projected: PTS: 7.3, REB: 8.2, AST: 2.1
#   📈 Fantasy: 20.5 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Cam Thomas
#   📊 Last 5: PTS: 13.4, REB: 2.2, AST: 1.6, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 19.5
#   🎯 Projected: PTS: 14.1, REB: 2.3, AST: 1.7
#   📊 Fantasy: 17.9 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 AJ Green
#   📊 Last 5: PTS: 8.6, REB: 2.2, AST: 2.8, STL: 0.6, BLK: 0.0
#   ⏱️ Minutes: 31.8
#   🎯 Projected: PTS: 9.0, REB: 2.3, AST: 2.9
#   📊 Fantasy: 17.5 (Role Player)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Cole Anthony
#   📊 Last 5: PTS: 6.0, REB: 2.0, AST: 3.0, STL: 0.4, BLK: 0.4
#   ⏱️ Minutes: 15.1
#   🎯 Projected: PTS: 6.3, REB: 2.1, AST: 3.1
#   📊 Fantasy: 14.8 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Amir Coffey
#   📊 Last 5: PTS: 5.8, REB: 2.4, AST: 1.8, STL: 0.6, BLK: 0.2
#   ⏱️ Minutes: 18.2
#   🎯 Projected: PTS: 6.1, REB: 2.5, AST: 1.9
#   📊 Fantasy: 14.2 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Pete Nance
#   📊 Last 5: PTS: 5.2, REB: 2.4, AST: 0.8, STL: 0.0, BLK: 0.4
#   ⏱️ Minutes: 13.0
#   🎯 Projected: PTS: 5.5, REB: 2.5, AST: 0.8
#   📊 Fantasy: 10.2 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Gary Trent Jr.
#   📊 Last 5: PTS: 4.6, REB: 0.2, AST: 0.8, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 11.0
#   🎯 Projected: PTS: 4.8, REB: 0.2, AST: 0.8
#   📊 Fantasy: 6.3 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Andre Jackson Jr.
#   📊 Last 5: PTS: 0.8, REB: 1.6, AST: 0.2, STL: 0.2, BLK: 0.0
#   ⏱️ Minutes: 4.8
#   🎯 Projected: PTS: 0.8, REB: 1.7, AST: 0.2
#   📊 Fantasy: 3.4 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Thanasis Antetokounmpo
#   📊 Last 5: PTS: 1.0, REB: 1.2, AST: 0.4, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 3.2
#   🎯 Projected: PTS: 1.0, REB: 1.3, AST: 0.4
#   📊 Fantasy: 3.2 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# 🏠 Gary Harris
#   📊 Last 5: PTS: 0.4, REB: 0.6, AST: 1.0, STL: 0.0, BLK: 0.2
#   ⏱️ Minutes: 11.0
#   🎯 Projected: PTS: 0.4, REB: 0.6, AST: 1.0
#   📊 Fantasy: 3.0 (Deep Bench)
#   🎯 Matchup: Average Defense ⚖️
#
# ==================================================
# Cleveland Cavaliers PLAYER PROJECTIONS
# ==================================================
#
# 🛣️ Jarrett Allen
#   📊 Last 5: PTS: 19.6, REB: 11.6, AST: 1.4, STL: 1.0, BLK: 1.2
#   ⏱️ Minutes: 29.1
#   🎯 Projected: PTS: 18.1, REB: 10.7, AST: 1.3
#   ⭐ Fantasy: 37.8 (Star)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Donovan Mitchell
#   📊 Last 5: PTS: 24.4, REB: 4.2, AST: 4.6, STL: 1.8, BLK: 0.0
#   ⏱️ Minutes: 29.9
#   🎯 Projected: PTS: 22.5, REB: 3.9, AST: 4.2
#   ⭐ Fantasy: 35.5 (Star)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Darius Garland
#   📊 Last 5: PTS: 22.0, REB: 1.6, AST: 7.0, STL: 1.2, BLK: 0.2
#   ⏱️ Minutes: 31.0
#   🎯 Projected: PTS: 20.3, REB: 1.5, AST: 6.5
#   ⭐ Fantasy: 33.9 (Starter)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ James Harden
#   📊 Last 5: PTS: 17.4, REB: 4.0, AST: 8.2, STL: 1.0, BLK: 0.4
#   ⏱️ Minutes: 31.4
#   🎯 Projected: PTS: 16.0, REB: 3.7, AST: 7.6
#   ⭐ Fantasy: 32.3 (Starter)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Evan Mobley
#   📊 Last 5: PTS: 14.0, REB: 6.8, AST: 1.8, STL: 0.4, BLK: 0.8
#   ⏱️ Minutes: 27.6
#   🎯 Projected: PTS: 12.9, REB: 6.3, AST: 1.7
#   📈 Fantasy: 24.9 (Role Player)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Dennis Schröder
#   📊 Last 5: PTS: 12.0, REB: 2.0, AST: 4.6, STL: 1.6, BLK: 0.2
#   ⏱️ Minutes: 23.7
#   🎯 Projected: PTS: 11.1, REB: 1.8, AST: 4.2
#   📈 Fantasy: 22.9 (Role Player)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Jaylon Tyson
#   📊 Last 5: PTS: 9.8, REB: 5.6, AST: 1.4, STL: 0.8, BLK: 0.4
#   ⏱️ Minutes: 23.4
#   🎯 Projected: PTS: 9.0, REB: 5.2, AST: 1.3
#   📊 Fantasy: 19.7 (Role Player)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Keon Ellis
#   📊 Last 5: PTS: 7.6, REB: 2.4, AST: 2.0, STL: 1.4, BLK: 1.2
#   ⏱️ Minutes: 22.3
#   🎯 Projected: PTS: 7.0, REB: 2.2, AST: 1.8
#   📊 Fantasy: 18.9 (Role Player)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Dean Wade
#   📊 Last 5: PTS: 6.0, REB: 4.8, AST: 1.6, STL: 0.8, BLK: 0.6
#   ⏱️ Minutes: 21.3
#   🎯 Projected: PTS: 5.5, REB: 4.4, AST: 1.5
#   📊 Fantasy: 16.7 (Role Player)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ De'Andre Hunter
#   📊 Last 5: PTS: 12.0, REB: 1.8, AST: 0.6, STL: 0.8, BLK: 0.0
#   ⏱️ Minutes: 22.8
#   🎯 Projected: PTS: 11.1, REB: 1.7, AST: 0.6
#   📊 Fantasy: 14.8 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Lonzo Ball
#   📊 Last 5: PTS: 2.4, REB: 4.6, AST: 2.4, STL: 1.6, BLK: 0.2
#   ⏱️ Minutes: 18.3
#   🎯 Projected: PTS: 2.2, REB: 4.2, AST: 2.2
#   📊 Fantasy: 14.3 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Sam Merrill
#   📊 Last 5: PTS: 9.4, REB: 2.8, AST: 1.6, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 25.9
#   🎯 Projected: PTS: 8.7, REB: 2.6, AST: 1.5
#   📊 Fantasy: 13.2 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Thomas Bryant
#   📊 Last 5: PTS: 5.8, REB: 3.2, AST: 0.6, STL: 0.2, BLK: 0.4
#   ⏱️ Minutes: 12.7
#   🎯 Projected: PTS: 5.3, REB: 2.9, AST: 0.6
#   📊 Fantasy: 11.0 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Craig Porter Jr.
#   📊 Last 5: PTS: 2.0, REB: 2.0, AST: 3.0, STL: 0.4, BLK: 0.2
#   ⏱️ Minutes: 13.6
#   🎯 Projected: PTS: 1.8, REB: 1.8, AST: 2.8
#   📊 Fantasy: 8.9 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Nae'Qwan Tomlin
#   📊 Last 5: PTS: 3.0, REB: 2.2, AST: 0.2, STL: 0.4, BLK: 0.0
#   ⏱️ Minutes: 10.0
#   🎯 Projected: PTS: 2.8, REB: 2.0, AST: 0.2
#   📊 Fantasy: 6.0 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Larry Nance Jr.
#   📊 Last 5: PTS: 2.2, REB: 2.6, AST: 0.6, STL: 0.2, BLK: 0.0
#   ⏱️ Minutes: 8.4
#   🎯 Projected: PTS: 2.0, REB: 2.4, AST: 0.6
#   📊 Fantasy: 5.9 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Tyrese Proctor
#   📊 Last 5: PTS: 3.0, REB: 0.4, AST: 0.8, STL: 0.4, BLK: 0.0
#   ⏱️ Minutes: 5.5
#   🎯 Projected: PTS: 2.8, REB: 0.4, AST: 0.7
#   📊 Fantasy: 4.5 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Tristan Enaruna
#   📊 Last 5: PTS: 2.0, REB: 1.8, AST: 0.5, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 5.9
#   🎯 Projected: PTS: 1.8, REB: 1.6, AST: 0.5
#   📊 Fantasy: 4.2 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# 🛣️ Darius Brown
#   📊 Last 5: PTS: 0.0, REB: 1.0, AST: 0.0, STL: 0.0, BLK: 0.0
#   ⏱️ Minutes: 2.7
#   🎯 Projected: PTS: 0.0, REB: 0.9, AST: 0.0
#   📊 Fantasy: 1.1 (Deep Bench)
#   🎯 Matchup: Weak Defense 🎯
#
# ======================================================================
